# %% [markdown]
# <div class="hero" dir="rtl" align="right" style="direction:rtl;text-align:right;">
#   <h1 style="direction:rtl;text-align:right;">Hw1 - Week 1 - Quant</h1>
#   <p>
#     هفته ۱ · تمرین خانگی  دوره مقدماتی تا پیشرفته کوآنت<br>
#     هر سؤال یک موقعیت مالی دارد و زیر آن یک سلول کد ناقص است.
#     بخش‌هایی که با <b># To Do</b> مشخص شده‌اند را خودت کامل کن.
#   </p>
#   <div class="hero-meta">
#     <span class="chip">if / else</span>
#     <span class="chip">variable</span>
#     <span class="chip">print</span>
#     <span class="chip">for</span>
#     <span class="chip">while</span>
#     <span class="chip">input</span>
#     <span class="chip">۳ آسان</span>
#     <span class="chip">۵ متوسط</span>
#     <span class="chip">۲ سخت</span>
#   </div>
# </div>

# %% [markdown]
# <div class="guide" dir="rtl" align="right" style="direction:rtl;text-align:right;">
#   <h2 style="direction:rtl;text-align:right;">۰) راهنمای شروع و فونت وزیر</h2>
#   <p>متن سؤال‌ها با فونت <b>وزیرمتن (Vazirmatn)</b> و راست‌چین طراحی شده است.
#   فونت داخل پوشه <span class="kbd">fonts</span> همین پروژه است و نوت‌بوک آن را از همان‌جا فراخوانی می‌کند.</p>
#   <div class="step"><b>مرحله ۱ — اجباری:</b> سلول کد پایین را همین حالا اجرا کن تا فونت و رنگ‌ها اعمال شود.</div>
#   <div class="step"><b>مرحله ۲ — پیشنهادی:</b> اگر می‌خواهی فونت روی کل ویندوز نصب شود، برو به پوشه <span class="kbd">fonts</span> و روی فایل‌های <span class="kbd">.ttf</span> راست‌کلیک کن و <b>Install</b> بزن.
#   راهنمای کامل‌تر داخل <span class="kbd">fonts/راهنمای_نصب_فونت.md</span> است.</div>
#   <div class="step"><b>مرحله ۳:</b> هر سؤال را بخوان، سلول کد زیرش را کامل کن، بعد اجرا کن و با خروجی نمونه مقایسه کن.</div>
#   <p>اگر فونت دیده نشد: مطمئن شو نوت‌بوک را از پوشه <span class="kbd">W1</span> باز کرده‌ای، بعد همین سلول اول را دوباره Run کن.</p>
# </div>

# %%
# این سلول را اول از همه اجرا کن تا فونت وزیر و استایل سؤال‌ها فعال شود.
from IPython.display import HTML, display
from pathlib import Path

font_dir = Path("fonts")
needed = [
    "Vazirmatn-Regular.woff2",
    "Vazirmatn-Medium.woff2",
    "Vazirmatn-Bold.woff2",
    "notebook_style.html",
]
missing = [name for name in needed if not (font_dir / name).exists()]
if missing:
    print("هشدار: این فایل‌ها پیدا نشد:", ", ".join(missing))
    print("نوت‌بوک را از پوشه پروژه باز کن.")
else:
    print("فونت وزیر از پوشه fonts آماده است.")

style = Path("fonts/notebook_style.html").read_text(encoding="utf-8")
display(HTML(style))
print("استایل و فونت وزیر اعمال شد. حالا سؤال‌ها باید فارسی و رنگی دیده شوند.")

# %% [markdown]
# <div class="help" dir="rtl" align="right" style="direction:rtl;text-align:right;">
#   <h2 style="direction:rtl;text-align:right;">مفاهیم کمکی که ممکن است در بعضی سؤال‌ها ببینی</h2>
#   <p>درس اصلی همین‌هاست: <code>print</code> · <code>variable</code> · <code>input</code> · <code>if / else</code> · <code>for</code> · <code>while</code></p>
#   <ul>
#     <li><code>int(x)</code> متن را به عدد صحیح تبدیل می‌کند. <code>input</code> همیشه متن برمی‌گرداند.</li>
#     <li><code>range(n)</code> اعداد <code>0</code> تا <code>n-1</code> را می‌سازد. <code>range(1, n+1)</code> یعنی ۱ تا n.</li>
#     <li><code>%</code> باقیمانده تقسیم، <code>//</code> تقسیم صحیح، <code>**</code> توان.</li>
#     <li><code>==</code> برابر، <code>!=</code> نابرابر، <code>and</code> / <code>or</code> ترکیب شرط.</li>
#     <li><code>break</code> حلقه را قطع می‌کند. فقط جایی استفاده شده که لازم باشد.</li>
#     <li>لیست (<code>[]</code>) جزو درس اصلی نیست؛ اگر جایی لازم شد داخل همان سؤال توضیح کوتاه آمده است.</li>
#   </ul>
# </div>

# %% [markdown]
# <div class="toc" dir="rtl" align="right" style="direction:rtl;text-align:right;">
#   <h2 style="direction:rtl;text-align:right;">فهرست سؤال‌ها</h2>
# </div>
#
# 1. [سؤال ۱ — پیام بسته شدن NAV](#q1)
# 2. [سؤال ۲ — ارزش بازار موقعیت](#q2)
# 3. [سؤال ۳ — سیگنال حد ضرر](#q3)
# 4. [سؤال ۴ — پروفایل ریسک مشتری](#q4)
# 5. [سؤال ۵ — نسبت کفایت سرمایه](#q5)
# 6. [سؤال ۶ — جدول بهره ساده](#q6)
# 7. [سؤال ۷ — رشد مرکب NAV](#q7)
# 8. [سؤال ۸ — سقف و کف بازده هفتگی](#q8)
# 9. [سؤال ۹ — جدول استهلاک وام](#q9)
# 10. [سؤال ۱۰ — تخصیص بودجه سهم و اوراق](#q10)

# %% [markdown]
# <div class="guide" dir="rtl" align="right" style="direction:rtl;text-align:right;">
#   <h2 style="direction:rtl;text-align:right;">بخش آسان — سؤال ۱ تا ۳</h2>
#   <p>این سه سؤال برای گرم شدن است: چاپ، متغیر، ورودی، ضرب، و یک شرط ساده. خروجی باید دقیقاً مثل نمونه باشد.</p>
# </div>

# %% [markdown]
# ###### q1
#
# <div class="qcard" dir="rtl" align="right" style="direction:rtl;text-align:right;">
#   <div class="qbar" dir="rtl" style="direction:rtl;text-align:right;">
#     <span class="qnum">سؤال ۱</span>
#     <span class="tags">print · variable</span>
#   </div>
#   <h2 style="direction:rtl;text-align:right;">پیام بسته شدن NAV</h2>
#   <div class="qbody" dir="rtl" style="direction:rtl;text-align:right;">واحد صندوق درآمد ثابت در پایان روز، ارزش خالص دارایی (NAV) را روی سامانه می‌گذارد. یک متغیر برای همین پیام بساز و آن را چاپ کن. خروجی باید دقیقاً همان متن متغیر باشد.</div>
#   <div class="box tip" dir="rtl"><b>راهنما:</b> تابع <code>print</code> محتوای داخل پرانتز را نشان می‌دهد.</div>
#
#   <div class="io">
#     <div class="pane in">
#       <div class="pane-label">ورودی نمونه</div>
#       <pre dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate;white-space:pre;">این سؤال ورودی ندارد</pre>
#     </div>
#     <div class="pane out">
#       <div class="pane-label">خروجی نمونه</div>
#       <pre dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate;white-space:pre;">NAV امروز صندوق درآمد ثابت برابر ۱۰۰۰۰ ریال است.</pre>
#     </div>
#   </div>
#   <div class="box why" dir="rtl"><b>چرا این خروجی؟</b> ورودی لازم نیست. متن داخل متغیر دقیقاً همین جمله است؛ <code>print</code> همان را نشان می‌دهد.</div>
# </div>

# %%
message = "NAV امروز صندوق درآمد ثابت برابر ۱۰۰۰۰ ریال است."

# To Do: متغیر message را چاپ کن

# %% [markdown]
# ###### q2
#
# <div class="qcard" dir="rtl" align="right" style="direction:rtl;text-align:right;">
#   <div class="qbar" dir="rtl" style="direction:rtl;text-align:right;">
#     <span class="qnum">سؤال ۲</span>
#     <span class="tags">input · variable · print</span>
#   </div>
#   <h2 style="direction:rtl;text-align:right;">ارزش بازار موقعیت</h2>
#   <div class="qbody" dir="rtl" style="direction:rtl;text-align:right;">معامله‌گر تعداد سهم و قیمت هر سهم (تومان) را به تو می‌دهد. ارزش بازار موقعیت برابر است با <b>تعداد سهم × قیمت</b>. دو عدد را بخوان، حاصل را حساب کن و فقط همان عدد را چاپ کن.<br><br>مثال حل‌شده: اگر ۱۲۰ سهم داشته باشی و هر سهم ۲۵۰۰ تومان باشد، ارزش موقعیت ۱۲۰×۲۵۰۰=۳۰۰۰۰۰ تومان است.</div>
#   <div class="box tip" dir="rtl"><b>راهنما:</b> خروجی <code>input</code> متن است. قبل از ضرب باید <code>int</code> شود.</div>
#   <div class="box extra" dir="rtl"><b>راهنمای مفهوم کمکی:</b> <code>int(text)</code> متن عددی مثل <code>"120"</code> را به عدد <code>120</code> تبدیل می‌کند.</div>
#   <div class="io">
#     <div class="pane in">
#       <div class="pane-label">ورودی نمونه</div>
#       <pre dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate;white-space:pre;">120
# 2500</pre>
#     </div>
#     <div class="pane out">
#       <div class="pane-label">خروجی نمونه</div>
#       <pre dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate;white-space:pre;">300000</pre>
#     </div>
#   </div>
#   <div class="box why" dir="rtl"><b>چرا این خروجی؟</b> ۱۲۰ سهم با قیمت ۲۵۰۰ تومان یعنی ۱۲۰×۲۵۰۰=۳۰۰۰۰۰. همین عدد باید چاپ شود.</div>
# </div>

# %%
shares = int(input())
price = int(input())

# To Do: ارزش بازار را حساب کن و چاپ کن
value = 0
print(value)

# %% [markdown]
# ###### q3
#
# <div class="qcard" dir="rtl" align="right" style="direction:rtl;text-align:right;">
#   <div class="qbar" dir="rtl" style="direction:rtl;text-align:right;">
#     <span class="qnum">سؤال ۳</span>
#     <span class="tags">input · if / else</span>
#   </div>
#   <h2 style="direction:rtl;text-align:right;">سیگنال حد ضرر</h2>
#   <div class="qbody" dir="rtl" style="direction:rtl;text-align:right;">برای یک موقعیت خرید، حد ضرر از قبل تعیین شده است. دو عدد بگیر: قیمت فعلی و حد ضرر. اگر قیمت فعلی <b>کمتر یا مساوی</b> حد ضرر بود باید خارج شوی: <code>Stop</code>. وگرنه موقعیت را نگه می‌داری: <code>Hold</code>.<br><br>مثال حل‌شده: قیمت فعلی ۹۸ و حد ضرر ۱۰۰ است. چون ۹۸ از ۱۰۰ بزرگ‌تر نیست، سیگنال خروج است.</div>
#   <div class="box tip" dir="rtl"><b>راهنما:</b> شرط خروج این است: <code>spot &lt;= stop</code></div>
#
#   <div class="io">
#     <div class="pane in">
#       <div class="pane-label">ورودی نمونه</div>
#       <pre dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate;white-space:pre;">98
# 100</pre>
#     </div>
#     <div class="pane out">
#       <div class="pane-label">خروجی نمونه</div>
#       <pre dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate;white-space:pre;">Stop</pre>
#     </div>
#   </div>
#   <div class="box why" dir="rtl"><b>چرا این خروجی؟</b> قیمت فعلی ۹۸ است و حد ضرر ۱۰۰. چون ۹۸≤۱۰۰ شرط خروج برقرار است و باید <code>Stop</code> چاپ شود، نه Hold.</div>
# </div>

# %%
spot = int(input())
stop = int(input())

# To Do: با if / else سیگنال Stop یا Hold را چاپ کن
if True:
    print("Hold")

# %% [markdown]
# <div class="guide" dir="rtl" align="right" style="direction:rtl;text-align:right;">
#   <h2 style="direction:rtl;text-align:right;">بخش متوسط — سؤال ۴ تا ۸</h2>
#   <p>این‌جا چند حالت شرط، حلقه <code>for</code> و <code>while</code>، بهره ساده و مرکب، و پیدا کردن سقف و کف بازده را می‌بینی.</p>
# </div>

# %% [markdown]
# ###### q4
#
# <div class="qcard" dir="rtl" align="right" style="direction:rtl;text-align:right;">
#   <div class="qbar" dir="rtl" style="direction:rtl;text-align:right;">
#     <span class="qnum">سؤال ۴</span>
#     <span class="tags">if / elif / else</span>
#   </div>
#   <h2 style="direction:rtl;text-align:right;">پروفایل ریسک مشتری</h2>
#   <div class="qbody" dir="rtl" style="direction:rtl;text-align:right;">پرسشنامه ریسک شعبه یک امتیاز از ۰ تا ۱۰۰ می‌دهد. بر اساس امتیاز، پروفایل را چاپ کن:<br>۸۰ تا ۱۰۰ → <code>Speculative</code> · ۵۵ تا ۷۹ → <code>Aggressive</code> · ۳۰ تا ۵۴ → <code>Balanced</code> · کمتر از ۳۰ → <code>Conservative</code><br><br>مثال حل‌شده: امتیاز ۴۷ است. از ۸۰ و ۵۵ کمتر است، پس دو پروفایل پرریسک نیست. از ۳۰ بیشتر است؛ پس مشتری متعادل است و باید <code>Balanced</code> چاپ شود.</div>
#   <div class="box tip" dir="rtl"><b>راهنما:</b> شرط‌ها را از امتیاز بالاتر شروع کن تا تداخل نداشته باشند.</div>
#
#   <div class="io">
#     <div class="pane in">
#       <div class="pane-label">ورودی نمونه</div>
#       <pre dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate;white-space:pre;">47</pre>
#     </div>
#     <div class="pane out">
#       <div class="pane-label">خروجی نمونه</div>
#       <pre dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate;white-space:pre;">Balanced</pre>
#     </div>
#   </div>
#   <div class="box why" dir="rtl"><b>چرا این خروجی؟</b> امتیاز ۴۷ از ۸۰ و از ۵۵ کمتر است، پس Speculative و Aggressive نیست. از ۳۰ بیشتر است؛ پس بازه Balanced است.</div>
# </div>

# %%
score = int(input())

# To Do: بازه‌های پروفایل ریسک را با if / elif کامل کن
if score >= 80:
    print("Speculative")

# %% [markdown]
# ###### q5
#
# <div class="qcard" dir="rtl" align="right" style="direction:rtl;text-align:right;">
#   <div class="qbar" dir="rtl" style="direction:rtl;text-align:right;">
#     <span class="qnum">سؤال ۵</span>
#     <span class="tags">if / elif · //</span>
#   </div>
#   <h2 style="direction:rtl;text-align:right;">نسبت کفایت سرمایه</h2>
#   <div class="qbody" dir="rtl" style="direction:rtl;text-align:right;">ناظر بانکی دو عدد می‌گیرد: سرمایه نظارتی و دارایی موزون‌شده به ریسک (RWA). نسبت کفایت را به‌صورت درصد صحیح حساب کن: <code>capital * 100 // rwa</code> (قسمت اعشار لازم نیست).<br>اگر نسبت ۱۲ یا بیشتر بود <code>Well</code>، اگر ۸ تا ۱۱ بود <code>Adequate</code>، وگرنه <code>Short</code>.<br><br>مثال حل‌شده: سرمایه ۲۲ و RWA برابر ۲۰۰. نسبت = ۲۲×۱۰۰÷۲۰۰ = ۱۱. یازده از ۱۲ کمتر است پس Well نیست، ولی از ۸ کمتر هم نیست؛ پس Adequate.</div>
#   <div class="box tip" dir="rtl"><b>راهنما:</b> اول نسبت را در یک متغیر حساب کن، بعد همان را در <code>if</code>ها استفاده کن.</div>
#   <div class="box extra" dir="rtl"><b>راهنمای مفهوم کمکی:</b> عمل <code>//</code> تقسیم صحیح است: <code>11 // 2</code> می‌شود ۵، نه ۵٫۵.</div>
#   <div class="io">
#     <div class="pane in">
#       <div class="pane-label">ورودی نمونه</div>
#       <pre dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate;white-space:pre;">22
# 200</pre>
#     </div>
#     <div class="pane out">
#       <div class="pane-label">خروجی نمونه</div>
#       <pre dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate;white-space:pre;">Adequate</pre>
#     </div>
#   </div>
#   <div class="box why" dir="rtl"><b>چرا این خروجی؟</b> سرمایه ۲۲ و دارایی موزون‌شده ۲۰۰ است. نسبت یعنی ۲۲×۱۰۰÷۲۰۰=۱۱. یازده از ۱۲ کمتر و از ۸ بیشتر است؛ پس <code>Adequate</code>.</div>
# </div>

# %%
capital = int(input())
rwa = int(input())

# To Do: نسبت را حساب کن و بر اساس بازه Well / Adequate / Short چاپ کن
ratio = 0
print("Short")

# %% [markdown]
# ###### q6
#
# <div class="qcard" dir="rtl" align="right" style="direction:rtl;text-align:right;">
#   <div class="qbar" dir="rtl" style="direction:rtl;text-align:right;">
#     <span class="qnum">سؤال ۶</span>
#     <span class="tags">for · print</span>
#   </div>
#   <h2 style="direction:rtl;text-align:right;">جدول بهره ساده</h2>
#   <div class="qbody" dir="rtl" style="direction:rtl;text-align:right;">اصل سرمایه <code>P</code>، نرخ سالانه <code>r</code> درصد، و تعداد سال <code>n</code> را بگیر. با بهره <b>ساده</b>، بهره هر سال ثابت است و روی اصل حساب می‌شود، نه روی سود سال‌های قبل. ارزش در پایان سال t برابر است با <code>P + P * r * t // 100</code>. برای t از ۱ تا n، هر سال را در یک خط جدا چاپ کن.<br><br>مثال حل‌شده: اصل ۲۰۰، نرخ ۱۰٪، چهار سال. بهره هر سال ۲۰ است. سال ۱ → ۲۲۰، سال ۲ → ۲۴۰، سال ۳ → ۲۶۰، سال ۴ → ۲۸۰.</div>
#
#   <div class="box extra" dir="rtl"><b>راهنمای مفهوم کمکی:</b> <code>range(1, n+1)</code> اعداد ۱، ۲، ...، n را می‌دهد.</div>
#   <div class="io">
#     <div class="pane in">
#       <div class="pane-label">ورودی نمونه</div>
#       <pre dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate;white-space:pre;">200
# 10
# 4</pre>
#     </div>
#     <div class="pane out">
#       <div class="pane-label">خروجی نمونه</div>
#       <pre dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate;white-space:pre;">220
# 240
# 260
# 280</pre>
#     </div>
#   </div>
#   <div class="box why" dir="rtl"><b>چرا این خروجی؟</b> بهره هر سال ثابت است: ۲۰۰×۱۰÷۱۰۰=۲۰. سال ۱: ۲۰۰+۲۰=۲۲۰ · سال ۲: ۲۰۰+۴۰=۲۴۰ · سال ۳: ۲۶۰ · سال ۴: ۲۸۰. هر عدد در یک خط.</div>
# </div>

# %%
principal = int(input())
rate = int(input())
years = int(input())

# To Do: برای هر سال t از 1 تا n ارزش بهره ساده را چاپ کن
for t in range(1, 1):
    value = 0  # To Do
    print(value)

# %% [markdown]
# ###### q7
#
# <div class="qcard" dir="rtl" align="right" style="direction:rtl;text-align:right;">
#   <div class="qbar" dir="rtl" style="direction:rtl;text-align:right;">
#     <span class="qnum">سؤال ۷</span>
#     <span class="tags">for · variable</span>
#   </div>
#   <h2 style="direction:rtl;text-align:right;">رشد مرکب NAV</h2>
#   <div class="qbody" dir="rtl" style="direction:rtl;text-align:right;">NAV اولیه صندوق، نرخ رشد سالانه <code>r</code> درصد، و تعداد سال <code>n</code> را بگیر. این‌بار بهره <b>مرکب</b> است: هر سال رشد روی NAV همان سال حساب می‌شود. هر سال این کار را بکن: <code>nav = nav + nav * r // 100</code> و NAV پایان آن سال را چاپ کن.<br><br>مثال حل‌شده: NAV=۱۰۰۰، نرخ ۱۰٪، سه سال. سال ۱: ۱۰۰۰+۱۰۰=۱۱۰۰. سال ۲: بهره روی ۱۱۰۰ حساب می‌شود (نه روی ۱۰۰۰) یعنی ۱۱۰، پس ۱۲۱۰. سال ۳: ۱۲۱۰+۱۲۱=۱۳۳۱.</div>
#   <div class="box tip" dir="rtl"><b>راهنما:</b> یک متغیر <code>nav</code> را هر دور حلقه به‌روز کن؛ از اصل اولیه جدا نکن.</div>
#
#   <div class="io">
#     <div class="pane in">
#       <div class="pane-label">ورودی نمونه</div>
#       <pre dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate;white-space:pre;">1000
# 10
# 3</pre>
#     </div>
#     <div class="pane out">
#       <div class="pane-label">خروجی نمونه</div>
#       <pre dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate;white-space:pre;">1100
# 1210
# 1331</pre>
#     </div>
#   </div>
#   <div class="box why" dir="rtl"><b>چرا این خروجی؟</b> سال اول ۱۰۰۰+۱۰۰=۱۱۰۰. سال دوم بهره روی ۱۱۰۰ حساب می‌شود: ۱۱۰، پس ۱۲۱۰. سال سوم بهره روی ۱۲۱۰: ۱۲۱، پس ۱۳۳۱. هر سال در یک خط.</div>
# </div>

# %%
nav = int(input())
rate = int(input())
years = int(input())

# To Do: n سال سود مرکب را اعمال کن و هر سال nav را چاپ کن
for i in range(0):
    nav = nav  # To Do
    print(nav)

# %% [markdown]
# ###### q8
#
# <div class="qcard" dir="rtl" align="right" style="direction:rtl;text-align:right;">
#   <div class="qbar" dir="rtl" style="direction:rtl;text-align:right;">
#     <span class="qnum">سؤال ۸</span>
#     <span class="tags">for · if</span>
#   </div>
#   <h2 style="direction:rtl;text-align:right;">سقف و کف بازده هفتگی</h2>
#   <div class="qbody" dir="rtl" style="direction:rtl;text-align:right;">واحد تحلیل n بازده هفتگی (به درصد صحیح، ممکن است منفی باشد) دارد. اول n را بگیر، بعد n عدد. بزرگ‌ترین بازده (سقف) و کوچک‌ترین بازده (کف) را پیدا کن و در یک خط چاپ کن: اول سقف، بعد فاصله، بعد کف.<br><br>مثال حل‌شده: پنج هفته با بازده ۲، ۴−، ۷، ۰، ۳. از بین این‌ها ۷ از همه بزرگ‌تر و ۴− از همه کوچک‌تر است. خروجی باید <code>7 -4</code> باشد.</div>
#   <div class="box tip" dir="rtl"><b>راهنما:</b> اولین عدد را هم سقف و هم کف بگیر. بعد در حلقه اگر عددی بزرگ‌تر دیدی سقف را عوض کن؛ اگر کوچک‌تر بود کف را.</div>
#   <div class="box extra" dir="rtl"><b>راهنمای مفهوم کمکی:</b> لازم نیست لیست بسازی. می‌توانی اعداد را یکی‌یکی بخوانی و فقط دو متغیر max و min را نگه داری.</div>
#   <div class="io">
#     <div class="pane in">
#       <div class="pane-label">ورودی نمونه</div>
#       <pre dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate;white-space:pre;">5
# 2
# -4
# 7
# 0
# 3</pre>
#     </div>
#     <div class="pane out">
#       <div class="pane-label">خروجی نمونه</div>
#       <pre dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate;white-space:pre;">7 -4</pre>
#     </div>
#   </div>
#   <div class="box why" dir="rtl"><b>چرا این خروجی؟</b> پنج بازده: ۲، ۴−، ۷، ۰، ۳. بزرگ‌ترین ۷ و کوچک‌ترین ۴− است. اول سقف را چاپ کن، بعد یک فاصله، بعد کف.</div>
# </div>

# %%
n = int(input())
first = int(input())
best = first
worst = first

# To Do: بقیه n-1 عدد را بخوان و best / worst را به‌روز کن
for i in range(0):
    x = 0  # To Do: int(input())
    if False:
        best = x
    if False:
        worst = x

print(best, worst)

# %% [markdown]
# <div class="guide" dir="rtl" align="right" style="direction:rtl;text-align:right;">
#   <h2 style="direction:rtl;text-align:right;">بخش سخت — سؤال ۹ و ۱۰</h2>
#   <p>این دو سؤال چند مرحله پشت‌سرهم دارند. اول نمونه را روی کاغذ حساب کن، بعد کد را بنویس و با خروجی سبز مقایسه کن.</p>
# </div>

# %% [markdown]
# ###### q9
#
# <div class="qcard" dir="rtl" align="right" style="direction:rtl;text-align:right;">
#   <div class="qbar" dir="rtl" style="direction:rtl;text-align:right;">
#     <span class="qnum">سؤال ۹</span>
#     <span class="tags">while · if</span>
#   </div>
#   <h2 style="direction:rtl;text-align:right;">جدول استهلاک وام</h2>
#   <div class="qbody" dir="rtl" style="direction:rtl;text-align:right;">مانده بدهی <code>D</code>، نرخ بهره ماهانه <code>r</code> درصد، و قسط ثابت <code>pay</code> را بگیر. هر ماه به این ترتیب پیش برو، تا وقتی مانده صفر شود:<br>۱) بهره این ماه: <code>interest = remaining * r // 100</code><br>۲) مانده را با بهره جمع کن.<br>۳) اگر مانده جدید از قسط <b>کمتر یا مساوی</b> بود، کل مانده را بپرداز و ۰ چاپ کن، بعد حلقه تمام.<br>۴) وگرنه قسط کامل را کم کن و مانده جدید را چاپ کن.<br><br>مثال حل‌شده با D=۱۰۰۰، r=۱، pay=۴۰۰:<br>ماه ۱: بهره ۱۰، مانده ۱۰۱۰، پرداخت ۴۰۰ → ۶۱۰<br>ماه ۲: بهره ۶، مانده ۶۱۶، پرداخت ۴۰۰ → ۲۱۶<br>ماه ۳: بهره ۲، مانده ۲۱۸ که از ۴۰۰ کوچک‌تر است → پرداخت کامل، مانده ۰.</div>
#   <div class="box tip" dir="rtl"><b>راهنما:</b> هر دور حلقه باید مانده را چاپ کنی، حتی وقتی به صفر می‌رسد. مواظب باش حلقه بی‌نهایت نشود.</div>
#
#   <div class="io">
#     <div class="pane in">
#       <div class="pane-label">ورودی نمونه</div>
#       <pre dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate;white-space:pre;">1000
# 1
# 400</pre>
#     </div>
#     <div class="pane out">
#       <div class="pane-label">خروجی نمونه</div>
#       <pre dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate;white-space:pre;">610
# 216
# 0</pre>
#     </div>
#   </div>
#   <div class="box why" dir="rtl"><b>چرا این خروجی؟</b> ماه ۱: بهره ۱۰۰۰×۱÷۱۰۰=۱۰، مانده ۱۰۱۰−۴۰۰=۶۱۰. ماه ۲: ۶۱۰×۱٪=۶، مانده ۶۱۶−۴۰۰=۲۱۶. ماه ۳: بهره ۲، مانده ۲۱۸ که از قسط ۴۰۰ کوچک‌تر است؛ کل را می‌دهی و ۰ می‌ماند.</div>
# </div>

# %%
remaining = int(input())
rate = int(input())
pay = int(input())

# To Do: تا وقتی remaining صفر نشده، بهره و قسط را اعمال کن
while False:
    interest = 0  # To Do
    remaining = remaining  # To Do: remaining + interest
    if True:
        remaining = 0
    else:
        remaining = remaining  # To Do: کم کردن قسط
    print(remaining)

# %% [markdown]
# ###### q10
#
# <div class="qcard" dir="rtl" align="right" style="direction:rtl;text-align:right;">
#   <div class="qbar" dir="rtl" style="direction:rtl;text-align:right;">
#     <span class="qnum">سؤال ۱۰</span>
#     <span class="tags">for · if</span>
#   </div>
#   <h2 style="direction:rtl;text-align:right;">تخصیص بودجه سهم و اوراق</h2>
#   <div class="qbody" dir="rtl" style="direction:rtl;text-align:right;">مدیر پرتفوی بودجه <code>B</code> میلیون تومان دارد. قیمت هر سهم <code>ps</code> و قیمت هر ورقه <code>pb</code> است. فقط می‌تواند تعداد صحیح سهم و ورقه بخرد (کسری سهم نداریم). می‌خواهد ترکیبی انتخاب کند که <b>کمترین پول خرد</b> بماند. اگر چند ترکیب مانده یکسان داشتند، آن را بردار که <b>تعداد سهم بیشتری</b> دارد.<br><br>خروجی سه عدد در یک خط است: تعداد سهم، تعداد ورقه، پول خرد.<br><br>مثال حل‌شده با بودجه ۸۷، سهم ۲۰، ورقه ۱۳:<br>۰ سهم + ۶ ورقه → مانده ۹<br>۱ سهم + ۵ ورقه → مانده ۲<br>۲ سهم + ۳ ورقه → مانده ۸<br>۳ سهم + ۲ ورقه → مانده ۱<br>۴ سهم + ۰ ورقه → مانده ۷<br>کمترین خرد ۱ است؛ پس جواب <code>3 2 1</code>.</div>
#   <div class="box tip" dir="rtl"><b>راهنما:</b> روی تعداد سهم از ۰ تا حداکثر ممکن حلقه بزن. برای هر تعداد سهم، با باقی بودجه حداکثر ورقه را بخر و خرد را حساب کن.</div>
#   <div class="box extra" dir="rtl"><b>راهنمای مفهوم کمکی:</b> حداکثر تعداد سهم <code>B // ps</code> است. برای هر s، تعداد ورقه <code>(B - s * ps) // pb</code> است.</div>
#   <div class="io">
#     <div class="pane in">
#       <div class="pane-label">ورودی نمونه</div>
#       <pre dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate;white-space:pre;">87
# 20
# 13</pre>
#     </div>
#     <div class="pane out">
#       <div class="pane-label">خروجی نمونه</div>
#       <pre dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate;white-space:pre;">3 2 1</pre>
#     </div>
#   </div>
#   <div class="box why" dir="rtl"><b>چرا این خروجی؟</b> با ۳ سهم (۶۰) و ۲ ورقه (۲۶) جمع ۸۶ می‌شود و ۱ میلیون خرد می‌ماند. ترکیب‌های دیگر خرد ۲، ۷، ۸ یا ۹ می‌گذارند. کمترین خرد همین ۱ است؛ پس <code>3 2 1</code>.</div>
# </div>

# %%
budget = int(input())
ps = int(input())
pb = int(input())
best_s = 0
best_b = 0
best_left = budget

# To Do: حلقه روی تعداد سهم و به‌روزرسانی بهترین ترکیب
for s in range(0, 1):
    b = 0
    left = budget
    if False:
        best_s = s
        best_b = b
        best_left = left

print(best_s, best_b, best_left)
