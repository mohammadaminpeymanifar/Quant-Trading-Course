# %% [markdown]
# <div class="hero" dir="rtl" align="right" style="direction:rtl;text-align:right;">
#   <h1 style="direction:rtl;text-align:right;">ده تمرین خانگی پایتون برای مدیریت مالی</h1>
#   <p>
#     هفته ۲ · تمرین خانگی · ایستگاه اول: پایتون مقدماتی · Zero to Quant<br>
#     ارشد مدیریت مالی — قیمت‌گذاری، بازده پرتفوی و محدودیت ریسک<br>
#     هر سؤال یک موقعیت مالی دارد، یک نمونه حل‌شده دارد، و زیر آن یک سلول کد ناقص است.
#     بخش‌هایی که با <b># To Do</b> مشخص شده‌اند را خودت کامل کن.
#   </p>
#   <div class="hero-meta">
#     <span class="chip">list</span>
#     <span class="chip">dictionary</span>
#     <span class="chip">tuple</span>
#     <span class="chip">set</span>
#     <span class="chip">string</span>
#     <span class="chip">۲ آسان</span>
#     <span class="chip">۵ متوسط</span>
#     <span class="chip">۳ سخت</span>
#   </div>
# </div>

# %% [markdown]
# <div class="guide" dir="rtl" align="right" style="direction:rtl;text-align:right;">
#   <h2 style="direction:rtl;text-align:right;">۰) راهنمای شروع و فونت وزیر</h2>
#   <p>متن سؤال‌ها با فونت <b>وزیرمتن (Vazirmatn)</b> و راست‌چین طراحی شده است.
#   فونت داخل پوشه <span class="kbd">fonts</span> همین پروژه است و نوت‌بوک آن را از همان‌جا فراخوانی می‌کند.</p>
#   <div class="step"><b>مرحله ۱ — اجباری:</b> سلول کد پایین را همین حالا اجرا کن تا فونت و رنگ‌ها اعمال شود.</div>
#   <div class="step"><b>مرحله ۲ — پیشنهادی:</b> اگر می‌خواهی فونت روی کل ویندوز نصب شود، برو به پوشه <span class="kbd">fonts</span> و روی فایل‌های <span class="kbd">.ttf</span> راست‌کلیک کن و <b>Install</b> بزن.
#   راهنمای کامل‌تر داخل <span class="kbd">fonts/راهنمای_نصب_فونت.md</span> است.</div>
#   <div class="step"><b>مرحله ۳:</b> هر سؤال را بخوان، نمونه و کادر سبز «حل نمونه» را روی کاغذ دنبال کن، بعد سلول کد زیرش را کامل کن و با خروجی نمونه مقایسه کن.</div>
#   <p>اگر فونت دیده نشد: مطمئن شو نوت‌بوک را از پوشه‌ای باز کرده‌ای که پوشه <span class="kbd">fonts</span> کنار آن است، بعد همین سلول اول را دوباره Run کن.</p>
# </div>

# %%
# این سلول را اول از همه اجرا کن تا فونت وزیر و استایل سؤال‌ها فعال شود.
from IPython.display import HTML, display
from pathlib import Path

font_dir = Path("fonts")
needed = [
    "Vazirmatn-Regular.woff2",
    "Vazirmatn-Medium.woff2",
    "Vazirmatn-Bold.woff2",
    "notebook_style.html",
]
missing = [name for name in needed if not (font_dir / name).exists()]
if missing:
    print("هشدار: این فایل‌ها پیدا نشد:", ", ".join(missing))
    print("نوت‌بوک را از پوشه پروژه باز کن.")
else:
    print("فونت وزیر از پوشه fonts آماده است.")

style = Path("fonts/notebook_style.html").read_text(encoding="utf-8")
display(HTML(style))
print("استایل و فونت وزیر اعمال شد. حالا سؤال‌ها باید فارسی و رنگی دیده شوند.")

# %% [markdown]
# <div class="help" dir="rtl" align="right" style="direction:rtl;text-align:right;">
#   <h2 style="direction:rtl;text-align:right;">مفاهیم کمکی که ممکن است در بعضی سؤال‌ها ببینی</h2>
#   <p>درس این هفته همین‌هاست: <code>list</code> · <code>dict</code> · <code>tuple</code> · <code>set</code> · متدهای <code>string</code></p>
#   <ul>
#     <li>لیست: <code>items[0]</code> و <code>items[1]</code> دو عضو اول، <code>items[-1]</code> آخر، <code>max(items)</code> بزرگ‌ترین عضو.</li>
#     <li>دیکشنری: <code>d[key]</code> مقدار کلید، <code>d[key] = v</code> نوشتن، <code>d.items()</code> پیمایش، <code>d.get(key, 0)</code> با پیش‌فرض صفر.</li>
#     <li>تاپل: مثل لیست است ولی عوض نمی‌شود. باز کردن: <code>a, b, c = row</code>.</li>
#     <li>مجموعه: عضو تکراری ندارد. اشتراک <code>&amp;</code> · اجتماع <code>|</code> · تفاضل <code>-</code>.</li>
#     <li>رشته: <code>split</code> متن را به واژه‌ها می‌شکند. <code>join</code> واژه‌ها را به یک متن برمی‌گرداند.</li>
#     <li><code>sorted(x)</code> یک لیست مرتب‌شده برمی‌گرداند. اگر عضوهایش عدد باشند، ترتیب عددی است.</li>
#     <li>از هفته قبل: <code>input</code> · <code>int</code> · <code>//</code> · <code>if</code> · <code>for</code> هنوز این‌جا لازم‌اند.</li>
#   </ul>
# </div>

# %% [markdown]
# <div class="toc" dir="rtl" align="right" style="direction:rtl;text-align:right;">
#   <h2 style="direction:rtl;text-align:right;">فهرست سؤال‌ها</h2>
# </div>
#
# 1. [سؤال ۱ — ایندکس قیمت تابلو](#q1)
# 2. [سؤال ۲ — خواندن کوپن از دیکشنری](#q2)
# 3. [سؤال ۳ — باز کردن تاپل قیمت کثیف](#q3)
# 4. [سؤال ۴ — شکستن سطر تابلو](#q4)
# 5. [سؤال ۵ — قله و آخرین NAV](#q5)
# 6. [سؤال ۶ — ورود و خروج نمادها](#q6)
# 7. [سؤال ۷ — سهم هر دارایی در بازده](#q7)
# 8. [سؤال ۸ — شکاف سررسید دارایی و بدهی](#q8)
# 9. [سؤال ۹ — برابری خرید و فروش اختیار](#q9)
# 10. [سؤال ۱۰ — سقف تمرکز و شاخص HHI](#q10)

# %% [markdown]
# <div class="guide" dir="rtl" align="right" style="direction:rtl;text-align:right;">
#   <h2 style="direction:rtl;text-align:right;">بخش آسان — سؤال ۱ و ۲</h2>
#   <p>محور این دو سؤال خود پایتون است: <b>ایندکس لیست</b> و <b>خواندن دیکشنری با کلید</b>. عدد مالی فقط یک تفریق یا یک ضرب ساده است.</p>
# </div>

# %% [markdown]
# ###### q1
#
# <div class="qcard" dir="rtl" align="right" style="direction:rtl;text-align:right;">
#   <div class="qbar" dir="rtl" style="direction:rtl;text-align:right;">
#     <span class="qnum">سؤال ۱</span>
#     <span class="tags">list · indexing</span>
#   </div>
#   <h2 style="direction:rtl;text-align:right;">ایندکس قیمت تابلو</h2>
#   <div class="qbody" dir="rtl" style="direction:rtl;text-align:right;"><b>مفهوم پایتون: ایندکس لیست.</b> لیست از صفر شمرده می‌شود. <b>quote[0]</b> عضو اول است و <b>quote[1]</b> عضو دوم. این‌جا عضو اول قیمت خرید بازار (bid) و عضو دوم قیمت فروش بازار (ask) است. اسپرد، از نظر مالی، همان اختلاف این دو قیمت است و هزینه عبور از بازار را نشان می‌دهد. سه خط چاپ کن: اول bid، بعد ask، بعد اسپرد که برابر است با ask منهای bid.<br><br>مثال حل‌شده: لیست <code>[718, 722]</code> است. ایندکس ۰ می‌شود ۷۱۸، ایندکس ۱ می‌شود ۷۲۲، و ۷۲۲−۷۱۸=۴.</div>
#   <div class="box tip" dir="rtl"><b>راهنما:</b> برای خط اول <code>quote[0]</code> را چاپ کن و برای خط دوم <code>quote[1]</code> را. اسپرد تفاضل همین دو متغیر است.</div>
#   <div class="box extra" dir="rtl"><b>راهنمای مفهوم کمکی:</b> خرید روی ask انجام می‌شود و فروش روی bid. فاصله‌شان اسپرد است.</div>
#   <div class="io">
#     <div class="pane in">
#       <div class="pane-label">ورودی نمونه</div>
#       <pre dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate;white-space:pre;">این سؤال ورودی ندارد</pre>
#     </div>
#     <div class="pane out">
#       <div class="pane-label">خروجی نمونه</div>
#       <pre dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate;white-space:pre;">718
# 722
# 4</pre>
#     </div>
#   </div>
#   <div class="box why" dir="rtl"><b>چرا این خروجی؟ حل نمونه:</b> قدم ۱: <b>quote[0]</b> برابر ۷۱۸ است؛ این خط اول است.<br>قدم ۲: <b>quote[1]</b> برابر ۷۲۲ است؛ این خط دوم است.<br>قدم ۳: ۷۲۲−۷۱۸=۴؛ این خط سوم است. قیمت میانی در این سؤال لازم نیست.</div>
# </div>

# %%
quote = [718, 722]

# To Do: bid و ask و اسپرد را در سه خط چاپ کن

# %% [markdown]
# ###### q2
#
# <div class="qcard" dir="rtl" align="right" style="direction:rtl;text-align:right;">
#   <div class="qbar" dir="rtl" style="direction:rtl;text-align:right;">
#     <span class="qnum">سؤال ۲</span>
#     <span class="tags">dict · indexing</span>
#   </div>
#   <h2 style="direction:rtl;text-align:right;">خواندن کوپن از دیکشنری</h2>
#   <div class="qbody" dir="rtl" style="direction:rtl;text-align:right;"><b>مفهوم پایتون: خواندن دیکشنری با کلید.</b> مقدار هر کلید را با <b>terms["face"]</b> و <b>terms["rate"]</b> می‌گیری. کلید را با نقل‌قول می‌نویسی چون متن است. face ارزش اسمی اوراق است و rate نرخ کوپن به درصد. کوپن سالانه روی همین اسمی حساب می‌شود: اسمی ضرب در نرخ، تقسیم صحیح بر ۱۰۰. فقط همان مبلغ را چاپ کن.<br><br>مثال حل‌شده: کلید face برابر ۱٬۰۰۰٬۰۰۰ و کلید rate برابر ۱۸ است. ۱٬۰۰۰٬۰۰۰×۱۸=۱۸٬۰۰۰٬۰۰۰ و ۱۸٬۰۰۰٬۰۰۰//۱۰۰=۱۸۰٬۰۰۰.</div>
#   <div class="box tip" dir="rtl"><b>راهنما:</b> اول دو کلید را در دو متغیر بریز، بعد <code>face * rate // 100</code> را چاپ کن.</div>
#   <div class="box extra" dir="rtl"><b>راهنمای مفهوم کمکی:</b> ناشر کوپن را نسبت به ارزش اسمی تعهد می‌کند. قیمت بازار کلید این دیکشنری نیست.</div>
#   <div class="io">
#     <div class="pane in">
#       <div class="pane-label">ورودی نمونه</div>
#       <pre dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate;white-space:pre;">این سؤال ورودی ندارد</pre>
#     </div>
#     <div class="pane out">
#       <div class="pane-label">خروجی نمونه</div>
#       <pre dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate;white-space:pre;">180000</pre>
#     </div>
#   </div>
#   <div class="box why" dir="rtl"><b>چرا این خروجی؟ حل نمونه:</b> قدم ۱: <b>terms["face"]</b> عدد ۱٬۰۰۰٬۰۰۰ را برمی‌گرداند.<br>قدم ۲: <b>terms["rate"]</b> عدد ۱۸ را برمی‌گرداند.<br>قدم ۳: ضرب این دو و تقسیم صحیح بر ۱۰۰ می‌شود ۱۸۰٬۰۰۰. خروجی فقط همین یک عدد است.</div>
# </div>

# %%
terms = {"face": 1000000, "rate": 18}

# To Do: با کلیدهای دیکشنری، مبلغ کوپن سالانه را چاپ کن

# %% [markdown]
# <div class="guide" dir="rtl" align="right" style="direction:rtl;text-align:right;">
#   <h2 style="direction:rtl;text-align:right;">بخش متوسط — سؤال ۳ تا ۷</h2>
#   <p>سؤال ۳ تا ۵ هنوز روی خود پایتون است: <b>باز کردن تاپل</b>، <b>split</b>، و <b>max</b> همراه ایندکس منفی. از سؤال ۶ به بعد ترکیب مفهوم مالی و کد بیشتر می‌شود.</p>
# </div>

# %% [markdown]
# ###### q3
#
# <div class="qcard" dir="rtl" align="right" style="direction:rtl;text-align:right;">
#   <div class="qbar" dir="rtl" style="direction:rtl;text-align:right;">
#     <span class="qnum">سؤال ۳</span>
#     <span class="tags">tuple · unpack</span>
#   </div>
#   <h2 style="direction:rtl;text-align:right;">باز کردن تاپل قیمت کثیف</h2>
#   <div class="qbody" dir="rtl" style="direction:rtl;text-align:right;"><b>مفهوم پایتون: باز کردن تاپل.</b> با یک خط <b>name, clean, accrued = bond</b> سه مقدار تاپل هم‌زمان داخل سه متغیر می‌ریزد. ترتیب تاپل این است: نماد، قیمت پاک، سود تعهدی. سود تعهدی از قبل حساب شده و داخل تاپل است. از نظر مالی، قیمت کثیف مبلغی است که خریدار می‌پردازد و برابر است با قیمت پاک به‌علاوه سود تعهدی. یک خط چاپ کن: <code>NAME DIRTY</code>.<br><br>مثال حل‌شده: تاپل <code>("AKHZA", 980000, 45000)</code> باز می‌شود. نماد AKHZA، پاک ۹۸۰٬۰۰۰، سود تعهدی ۴۵٬۰۰۰. جمع این دو قیمت ۱٬۰۲۵٬۰۰۰ است، پس خروجی <code>AKHZA 1025000</code>.</div>
#   <div class="box tip" dir="rtl"><b>راهنما:</b> بعد از باز کردن تاپل، <code>print(name, clean + accrued)</code> همان یک خط را می‌سازد.</div>
#   <div class="box extra" dir="rtl"><b>راهنمای مفهوم کمکی:</b> تابلو معمولاً قیمت پاک را نشان می‌دهد. سود تعهدی سهم فروشنده از کوپن روزهای گذشته است و به قیمت پاک اضافه می‌شود.</div>
#   <div class="io">
#     <div class="pane in">
#       <div class="pane-label">ورودی نمونه</div>
#       <pre dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate;white-space:pre;">این سؤال ورودی ندارد</pre>
#     </div>
#     <div class="pane out">
#       <div class="pane-label">خروجی نمونه</div>
#       <pre dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate;white-space:pre;">AKHZA 1025000</pre>
#     </div>
#   </div>
#   <div class="box why" dir="rtl"><b>چرا این خروجی؟ حل نمونه:</b> قدم ۱: باز کردن تاپل، متغیر name را AKHZA می‌کند.<br>قدم ۲: clean برابر ۹۸۰٬۰۰۰ و accrued برابر ۴۵٬۰۰۰ می‌شود.<br>قدم ۳: ۹۸۰٬۰۰۰+۴۵٬۰۰۰=۱٬۰۲۵٬۰۰۰. چاپ با یک فاصله بین نماد و عدد انجام می‌شود.</div>
# </div>

# %%
bond = ("AKHZA", 980000, 45000)

# To Do: تاپل را باز کن و نماد و قیمت کثیف را در یک خط چاپ کن

# %% [markdown]
# ###### q4
#
# <div class="qcard" dir="rtl" align="right" style="direction:rtl;text-align:right;">
#   <div class="qbar" dir="rtl" style="direction:rtl;text-align:right;">
#     <span class="qnum">سؤال ۴</span>
#     <span class="tags">string · split</span>
#   </div>
#   <h2 style="direction:rtl;text-align:right;">شکستن سطر تابلو</h2>
#   <div class="qbody" dir="rtl" style="direction:rtl;text-align:right;"><b>مفهوم پایتون: split.</b> متد <b>split(":")</b> متن را از روی دونقطه به یک لیست می‌شکند. سطر تابلو به شکل <code>TICKER:BID:ASK</code> می‌آید: نماد، قیمت خرید، قیمت فروش. بعد از شکستن، هر بخش را در یک خط جدا چاپ کن. قیمت‌ها را به عدد تبدیل نکن.<br><br>مثال حل‌شده: متن <code>FOOLAD:718:722</code> سه تکه دارد. تکه اول FOOLAD، تکه دوم 718 و تکه سوم 722 است. هر تکه یک خط می‌شود.</div>
#   <div class="box tip" dir="rtl"><b>راهنما:</b> نتیجه <code>split</code> یک لیست سه‌تایی است. با یک حلقه <code>for</code>، یا با سه ایندکس، هر عضو را چاپ کن.</div>
#   <div class="box extra" dir="rtl"><b>راهنمای مفهوم کمکی:</b> دونقطه جداکننده میدان‌های تابلو است. خود دونقطه داخل لیست خروجی <code>split</code> نمی‌ماند.</div>
#   <div class="io">
#     <div class="pane in">
#       <div class="pane-label">ورودی نمونه</div>
#       <pre dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate;white-space:pre;">FOOLAD:718:722</pre>
#     </div>
#     <div class="pane out">
#       <div class="pane-label">خروجی نمونه</div>
#       <pre dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate;white-space:pre;">FOOLAD
# 718
# 722</pre>
#     </div>
#   </div>
#   <div class="box why" dir="rtl"><b>چرا این خروجی؟ حل نمونه:</b> قدم ۱: <b>split(":")</b> لیست <code>["FOOLAD", "718", "722"]</code> را می‌سازد.<br>قدم ۲: عضو ۰ نماد است و خط اول می‌شود.<br>قدم ۳: عضو ۱ و عضو ۲ هنوز متن‌اند و همان‌طور در دو خط بعد چاپ می‌شوند. اسپرد این سؤال نیست.</div>
# </div>

# %%
text = input()

# To Do: متن را از روی دونقطه بشکن و هر بخش را در یک خط چاپ کن

# %% [markdown]
# ###### q5
#
# <div class="qcard" dir="rtl" align="right" style="direction:rtl;text-align:right;">
#   <div class="qbar" dir="rtl" style="direction:rtl;text-align:right;">
#     <span class="qnum">سؤال ۵</span>
#     <span class="tags">list · max</span>
#   </div>
#   <h2 style="direction:rtl;text-align:right;">قله و آخرین NAV</h2>
#   <div class="qbody" dir="rtl" style="direction:rtl;text-align:right;"><b>مفهوم پایتون: max و ایندکس منفی.</b> <b>max(nav)</b> بزرگ‌ترین عضو لیست را برمی‌گرداند و <b>nav[-1]</b> آخرین عضو است، بدون اینکه طول لیست را بشماری. سری NAV از قدیمی به جدید چیده شده. خط اول قله سری را چاپ کن و خط دوم NAV امروز را، که همان عضو آخر است.<br><br>مثال حل‌شده: لیست <code>[100, 110, 105, 120, 108]</code> پنج عضو دارد. بزرگ‌ترین عضو ۱۲۰ است. عضو آخر ۱۰۸ است. خروجی همین دو عدد در دو خط است.</div>
#   <div class="box tip" dir="rtl"><b>راهنما:</b> درصد افت را حساب نکن. فقط نتیجه <code>max</code> و بعد <code>nav[-1]</code> را چاپ کن.</div>
#   <div class="box extra" dir="rtl"><b>راهنمای مفهوم کمکی:</b> قله، بالاترین NAV همین دوره است. آخرین عضو، ارزش امروز هر واحد صندوق است.</div>
#   <div class="io">
#     <div class="pane in">
#       <div class="pane-label">ورودی نمونه</div>
#       <pre dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate;white-space:pre;">این سؤال ورودی ندارد</pre>
#     </div>
#     <div class="pane out">
#       <div class="pane-label">خروجی نمونه</div>
#       <pre dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate;white-space:pre;">120
# 108</pre>
#     </div>
#   </div>
#   <div class="box why" dir="rtl"><b>چرا این خروجی؟ حل نمونه:</b> قدم ۱: <b>max(nav)</b> بین ۱۰۰ و ۱۱۰ و ۱۰۵ و ۱۲۰ و ۱۰۸، عدد ۱۲۰ را برمی‌گرداند.<br>قدم ۲: <b>nav[-1]</b> از ته لیست یکی می‌شمارد و ۱۰۸ را می‌دهد. nav[0] برابر ۱۰۰ است و خط دوم نیست.</div>
# </div>

# %%
nav = [100, 110, 105, 120, 108]

# To Do: قله و آخرین NAV را در دو خط چاپ کن

# %% [markdown]
# ###### q6
#
# <div class="qcard" dir="rtl" align="right" style="direction:rtl;text-align:right;">
#   <div class="qbar" dir="rtl" style="direction:rtl;text-align:right;">
#     <span class="qnum">سؤال ۶</span>
#     <span class="tags">set · difference</span>
#   </div>
#   <h2 style="direction:rtl;text-align:right;">ورود و خروج نمادها</h2>
#   <div class="qbody" dir="rtl" style="direction:rtl;text-align:right;">دفتر پرتفوی دو خط می‌دهد: نمادهای دیروز و نمادهای امروز. بعد از بازچینش، بعضی نام‌ها بسته شده‌اند و بعضی نام تازه آمده است. نام‌های مشترک یعنی موقعیتی که نگه داشته شده و در این سؤال چاپ نمی‌شود.<br>خط اول فروش‌هاست: نمادهایی که دیروز بودند و امروز نیستند، به شکل <code>Sold: NAME ...</code> و به ترتیب الفبا.<br>خط دوم خریدهاست: نمادهایی که امروز هستند و دیروز نبودند، به شکل <code>Bought: NAME ...</code> و به ترتیب الفبا.<br><br>مثال حل‌شده: دیروز فولاد، شپنا، فارس و مپنا بوده. امروز فولاد، فارس، کگل و همراه مانده. فولاد و فارس مشترک‌اند. فروش‌ها مپنا و شپنا هستند. خریدها همراه و کگل هستند.</div>
#   <div class="box tip" dir="rtl"><b>راهنما:</b> تفاضل <code>yesterday - today</code> فروش است و <code>today - yesterday</code> خرید. هر مجموعه را <code>sorted</code> کن و با فاصله به برچسب بچسبان.</div>
#   <div class="box extra" dir="rtl"><b>راهنمای مفهوم کمکی:</b> اختلاف دو دفتر، همان تجزیه نگهداشت و معامله است. نام فروخته‌شده ریسکی است که دیگر در پرتفوی نیست و نام خریده‌شده ریسک تازه است. نام مشترک در بازده دیروز و امروز هر دو حضور دارد.</div>
#   <div class="io">
#     <div class="pane in">
#       <div class="pane-label">ورودی نمونه</div>
#       <pre dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate;white-space:pre;">FOOLAD SHPNA FARS MAPNA
# FOOLAD FARS KEGOL HAMRAH</pre>
#     </div>
#     <div class="pane out">
#       <div class="pane-label">خروجی نمونه</div>
#       <pre dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate;white-space:pre;">Sold: MAPNA SHPNA
# Bought: HAMRAH KEGOL</pre>
#     </div>
#   </div>
#   <div class="box why" dir="rtl"><b>چرا این خروجی؟ حل نمونه:</b> اشتراک دو روز FOOLAD و FARS است و چاپ نمی‌شود.<br>فروش = دیروز منهای امروز = {MAPNA, SHPNA}. الفبا MAPNA را قبل از SHPNA می‌گذارد.<br>خرید = امروز منهای دیروز = {HAMRAH, KEGOL}. الفبا HAMRAH را قبل از KEGOL می‌گذارد.<br>برچسب و نام‌ها با یک فاصله جدا می‌شوند: <code>Sold: MAPNA SHPNA</code>.</div>
# </div>

# %%
yesterday = set(input().split())
today = set(input().split())

# To Do: خط فروش و خط خرید را الفبایی چاپ کن

# %% [markdown]
# ###### q7
#
# <div class="qcard" dir="rtl" align="right" style="direction:rtl;text-align:right;">
#   <div class="qbar" dir="rtl" style="direction:rtl;text-align:right;">
#     <span class="qnum">سؤال ۷</span>
#     <span class="tags">dict · for</span>
#   </div>
#   <h2 style="direction:rtl;text-align:right;">سهم هر دارایی در بازده</h2>
#   <div class="qbody" dir="rtl" style="direction:rtl;text-align:right;">بازده پرتفوی، جمع سهم تک‌تک دارایی‌هاست. وزن‌ها و بازده‌ها هر کدام یک دیکشنری‌اند و کلیدها یکی است. وزن و بازده هر دو به درصد صحیح‌اند. سهم یک دارایی در بازده پرتفوی برابر است با وزن ضرب در بازده، تقسیم صحیح بر ۱۰۰. برای هر دارایی یک خط <code>NAME CONTRIB</code> به ترتیب دیکشنری وزن‌ها چاپ کن، و در خط آخر جمع همین سهم‌ها را به شکل <code>Total X</code> بنویس.<br><br>مثال حل‌شده: فولاد وزن ۵۰ و بازده ۸ دارد، پس سهمش ۴ واحد درصد است. شپنا وزن ۳۰ و بازده ۱۰− دارد، پس سهمش ۳− است. نقد وزن ۲۰ و بازده ۵ دارد، پس سهمش ۱ است. جمع ۴+(−۳)+۱=۲.</div>
#   <div class="box tip" dir="rtl"><b>راهنما:</b> روی <code>weights.items()</code> حلقه بزن. بازده همان نماد را از دیکشنری دوم بخوان: <code>returns[name]</code>. یک متغیر برای جمع سهم‌ها نگه دار.</div>
#   <div class="box extra" dir="rtl"><b>راهنمای مفهوم کمکی:</b> این ساده‌ترین شکل نسبت‌دادن عملکرد است. وزن ۵۰ درصد در بازده ۸ درصد، ۴ واحد از بازده کل پرتفوی را می‌سازد. شپنا با اینکه وزن کوچک‌تری دارد، به‌خاطر بازده منفی بازده پرتفوی را پایین کشیده است.</div>
#   <div class="io">
#     <div class="pane in">
#       <div class="pane-label">ورودی نمونه</div>
#       <pre dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate;white-space:pre;">این سؤال ورودی ندارد</pre>
#     </div>
#     <div class="pane out">
#       <div class="pane-label">خروجی نمونه</div>
#       <pre dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate;white-space:pre;">FOOLAD 4
# SHPNA -3
# Cash 1
# Total 2</pre>
#     </div>
#   </div>
#   <div class="box why" dir="rtl"><b>چرا این خروجی؟ حل نمونه:</b> ۵۰×۸//۱۰۰=۴، پس خط اول <code>FOOLAD 4</code>.<br>۳۰×(−۱۰)//۱۰۰=−۳، پس خط دوم <code>SHPNA -3</code>. علامت منفی باید بماند.<br>۲۰×۵//۱۰۰=۱، پس خط سوم <code>Cash 1</code>.<br>جمع سه سهم ۲ است و خط آخر دقیقاً <code>Total 2</code> است.</div>
# </div>

# %%
weights = {"FOOLAD": 50, "SHPNA": 30, "Cash": 20}
returns = {"FOOLAD": 8, "SHPNA": -10, "Cash": 5}

# To Do: سهم هر دارایی و جمع کل را چاپ کن

# %% [markdown]
# <div class="guide" dir="rtl" align="right" style="direction:rtl;text-align:right;">
#   <h2 style="direction:rtl;text-align:right;">بخش سخت — سؤال ۸ تا ۱۰</h2>
#   <p>این سه سؤال چند مرحله دارند: شکاف سررسید دارایی و بدهی، برابری اختیار خرید و فروش، و سقف تمرکز پرتفوی. کادر سبز را خط به خط دنبال کن، بعد کد را بنویس و با خروجی نمونه مقایسه کن.</p>
# </div>

# %% [markdown]
# ###### q8
#
# <div class="qcard" dir="rtl" align="right" style="direction:rtl;text-align:right;">
#   <div class="qbar" dir="rtl" style="direction:rtl;text-align:right;">
#     <span class="qnum">سؤال ۸</span>
#     <span class="tags">dict · set · sorted</span>
#   </div>
#   <h2 style="direction:rtl;text-align:right;">شکاف سررسید دارایی و بدهی</h2>
#   <div class="qbody" dir="rtl" style="direction:rtl;text-align:right;">میز خزانه‌داری جریان دارایی و بدهی را به تفکیک سال سررسید داده است. اول تعداد جریان‌های دارایی می‌آید، بعد همان تعداد خط <code>YEAR AMOUNT</code>. بعد تعداد جریان‌های بدهی، و بعد خط‌های بدهی با همین شکل. هر سال در هر طرف حداکثر یک بار آمده است.<br>شکاف آن سال برابر است با مبلغ دارایی منهای مبلغ بدهی. اگر سالی فقط در یک طرف باشد، طرف دیگر صفر است. سال‌ها را از کوچک به بزرگ چاپ کن، هر خط <code>YEAR GAP</code>.<br><br>مثال حل‌شده: دارایی سال ۱ تا ۴ به ترتیب ۱۰۰، ۸۰، ۲۰ و ۵۰ است. بدهی فقط سال ۱ تا ۳ به ترتیب ۹۰، ۱۰۰ و ۴۰ است. شکاف‌ها: ۱۰، ۲۰−، ۲۰− و ۵۰.</div>
#   <div class="box tip" dir="rtl"><b>راهنما:</b> سال را <code>int</code> کن و مبلغ را در دیکشنری همان طرف ذخیره کن. اجتماع کلیدها با <code>set(assets) | set(liabilities)</code> ساخته می‌شود. <code>d.get(year, 0)</code> اگر سال نباشد صفر می‌دهد. روی <code>sorted</code> همین سال‌ها حلقه بزن.</div>
#   <div class="box extra" dir="rtl"><b>راهنمای مفهوم کمکی:</b> شکاف مثبت یعنی در آن سال دارایی، بدهی را پوشش می‌دهد. شکاف منفی یعنی کمبود نقد و نیاز به تأمین مالی. سال ۴ در نمونه بدهی ندارد، پس کل جریان دارایی‌اش مازاد است. به این نما، شکاف سررسید یا funding gap می‌گویند.</div>
#   <div class="io">
#     <div class="pane in">
#       <div class="pane-label">ورودی نمونه</div>
#       <pre dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate;white-space:pre;">4
# 1 100
# 2 80
# 3 20
# 4 50
# 3
# 1 90
# 2 100
# 3 40</pre>
#     </div>
#     <div class="pane out">
#       <div class="pane-label">خروجی نمونه</div>
#       <pre dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate;white-space:pre;">1 10
# 2 -20
# 3 -20
# 4 50</pre>
#     </div>
#   </div>
#   <div class="box why" dir="rtl"><b>چرا این خروجی؟ حل نمونه:</b> سال ۱: ۱۰۰−۹۰=۱۰.<br>سال ۲: ۸۰−۱۰۰=−۲۰.<br>سال ۳: ۲۰−۴۰=−۲۰.<br>سال ۴ در بدهی نیست، پس ۰ کم می‌شود و شکاف ۵۰ می‌ماند.<br>ترتیب چاپ عددی است: ۱ بعد ۲ بعد ۳ بعد ۴. اگر سال ۴ را جا بیندازی، مازاد سررسید بلند دیده نمی‌شود.</div>
# </div>

# %%
n = int(input())
assets = {}
for i in range(n):
    year, amount = input().split()
    year = int(year)
    amount = int(amount)
    # To Do: مبلغ دارایی این سال را ذخیره کن

m = int(input())
liabilities = {}
for i in range(m):
    year, amount = input().split()
    year = int(year)
    amount = int(amount)
    # To Do: مبلغ بدهی این سال را ذخیره کن

# To Do: سال‌ها را از کوچک به بزرگ چاپ کن و شکاف هر سال را بنویس

# %% [markdown]
# ###### q9
#
# <div class="qcard" dir="rtl" align="right" style="direction:rtl;text-align:right;">
#   <div class="qbar" dir="rtl" style="direction:rtl;text-align:right;">
#     <span class="qnum">سؤال ۹</span>
#     <span class="tags">dict · if</span>
#   </div>
#   <h2 style="direction:rtl;text-align:right;">برابری خرید و فروش اختیار</h2>
#   <div class="qbody" dir="rtl" style="direction:rtl;text-align:right;">برابری خرید و فروش اختیار می‌گوید این دو بسته باید هم‌قیمت باشند:<br>بسته خرید = قیمت اختیار خرید + ارزش فعلی قیمت اعمال<br>بسته فروش = قیمت اختیار فروش + قیمت سهم<br>هر چهار عدد در دیکشنری آماده است. کلیدها: <code>Call</code>، <code>PVK</code>، <code>Put</code>، <code>S</code>. <code>PVK</code> از قبل تنزیل شده؛ دوباره نرخ نزن.<br>شکاف = بسته خرید − بسته فروش. بعد دقیقاً یکی از این سه خط را چاپ کن:<br>اگر شکاف مثبت بود <code>CallRich GAP</code><br>اگر شکاف منفی بود <code>PutRich GAP</code> و GAP قدرمطلق شکاف است<br>اگر شکاف صفر بود <code>Fair 0</code><br><br>مثال حل‌شده: اختیار خرید ۸۰ به‌علاوه ارزش فعلی قیمت اعمال ۹۶۰ می‌شود ۱۰۴۰. اختیار فروش ۵۰ به‌علاوه سهم ۱۰۰۰ می‌شود ۱۰۵۰. شکاف ۱۰۴۰−۱۰۵۰=−۱۰. سمت فروش ۱۰ واحد گران‌تر است، پس <code>PutRich 10</code>.</div>
#   <div class="box tip" dir="rtl"><b>راهنما:</b> دو جمع را جدا حساب کن و از هم کم کن. برای منفی‌نبودن فاصله از <code>-gap</code> استفاده کن، نه از تابع دیگر.</div>
#   <div class="box extra" dir="rtl"><b>راهنمای مفهوم کمکی:</b> CallRich یعنی بسته اختیار خرید نسبت به برابری گران است. PutRich یعنی بسته اختیار فروش و سهم گران است. Fair یعنی بازار این چهار قیمت را سازگار قیمت‌گذاری کرده. این سؤال فقط سمت گران و اندازه شکاف را می‌خواهد.</div>
#   <div class="io">
#     <div class="pane in">
#       <div class="pane-label">ورودی نمونه</div>
#       <pre dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate;white-space:pre;">این سؤال ورودی ندارد</pre>
#     </div>
#     <div class="pane out">
#       <div class="pane-label">خروجی نمونه</div>
#       <pre dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate;white-space:pre;">PutRich 10</pre>
#     </div>
#   </div>
#   <div class="box why" dir="rtl"><b>چرا این خروجی؟ حل نمونه:</b> بسته خرید ۸۰+۹۶۰=۱۰۴۰. بسته فروش ۵۰+۱۰۰۰=۱۰۵۰. شکاف −۱۰ است، پس شاخه مثبت و شاخه صفر اجرا نمی‌شوند. قدرمطلق ۱۰ است و برچسب سمت گران <code>PutRich</code> است. بین برچسب و عدد یک فاصله هست.</div>
# </div>

# %%
market = {"S": 1000, "PVK": 960, "Call": 80, "Put": 50}

# To Do: شکاف برابری را حساب کن و CallRich یا PutRich یا Fair را چاپ کن

# %% [markdown]
# ###### q10
#
# <div class="qcard" dir="rtl" align="right" style="direction:rtl;text-align:right;">
#   <div class="qbar" dir="rtl" style="direction:rtl;text-align:right;">
#     <span class="qnum">سؤال ۱۰</span>
#     <span class="tags">for · if · dict</span>
#   </div>
#   <h2 style="direction:rtl;text-align:right;">سقف تمرکز و شاخص HHI</h2>
#   <div class="qbody" dir="rtl" style="direction:rtl;text-align:right;">سیاست سرمایه‌گذاری دو محدودیت تمرکز دارد. سقف هر نام، از جمله نقد، ۲۵ درصد است و در متغیر <code>cap</code> آمده. علاوه بر آن باید شاخص هرفیندال (HHI) را گزارش کنی: جمع مربع وزن‌ها. اول n را بگیر، بعد n خط <code>NAME WEIGHT</code>. وزن‌ها درصد صحیح‌اند و جمعشان ۱۰۰ است.<br>هر نامی که وزنش <b>اکیداً بیشتر</b> از سقف بود یک خط <code>NAME EXCESS</code> می‌گیرد. EXCESS برابر وزن منهای سقف است و ترتیب همان ترتیب ورودی است. دقیقاً روی سقف بودن نقض نیست. بعد از همه نقض‌ها، در هر حال یک خط <code>HHI X</code> چاپ کن.<br><br>مثال حل‌شده: فولاد ۳۰، شپنا ۲۵، فارس ۱۵، نقد ۳۰. فولاد ۵ واحد بالای سقف است. شپنا دقیقاً ۲۵ است و چاپ نمی‌شود. فارس زیر سقف است. نقد هم ۵ واحد بالای سقف است. HHI = ۳۰²+۲۵²+۱۵²+۳۰² = ۹۰۰+۶۲۵+۲۲۵+۹۰۰ = ۲۶۵۰.</div>
#   <div class="box tip" dir="rtl"><b>راهنما:</b> مربع وزن یعنی <code>weight * weight</code>. آن را در هر دور به HHI اضافه کن، حتی اگر آن نام نقض نشده باشد.</div>
#   <div class="box extra" dir="rtl"><b>راهنمای مفهوم کمکی:</b> HHI برابر ۱۰٬۰۰۰ یعنی کل پرتفوی در یک نام است. هرچه عدد بزرگ‌تر باشد وزن‌ها در نام‌های کمتری جمع شده‌اند. در این سیاست، نقد هم یک نام است و از سقف ۲۵ معاف نیست؛ به همین دلیل CASH 30 نقض است.</div>
#   <div class="io">
#     <div class="pane in">
#       <div class="pane-label">ورودی نمونه</div>
#       <pre dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate;white-space:pre;">4
# FOOLAD 30
# SHPNA 25
# FARS 15
# CASH 30</pre>
#     </div>
#     <div class="pane out">
#       <div class="pane-label">خروجی نمونه</div>
#       <pre dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate;white-space:pre;">FOOLAD 5
# CASH 5
# HHI 2650</pre>
#     </div>
#   </div>
#   <div class="box why" dir="rtl"><b>چرا این خروجی؟ حل نمونه:</b> ۳۰&gt;۲۵ و اضافه وزن ۵ است، پس FOOLAD چاپ می‌شود. ۲۵ از ۲۵ بزرگ‌تر نیست، پس SHPNA خط ندارد. ۱۵ زیر سقف است.<br>نقد هم ۳۰ است و خط <code>CASH 5</code> بعد از فولاد می‌آید، چون ترتیب ورودی حفظ می‌شود.<br>مربع‌ها را حتی برای شپنا و فارس هم جمع کن: ۹۰۰+۶۲۵+۲۲۵+۹۰۰=۲۶۵۰. خط آخر همیشه هست.</div>
# </div>

# %%
cap = 25
n = int(input())
hhi = 0

for i in range(n):
    name, weight = input().split()
    weight = int(weight)
    # To Do: اگر وزن از سقف بیشتر بود نام و اضافه وزن را چاپ کن
    # To Do: مربع وزن را به hhi اضافه کن

# To Do: خط HHI را چاپ کن

# %% [markdown]
# <div class="guide" dir="rtl" align="right" style="direction:rtl;text-align:right;">
#   <h2 style="direction:rtl;text-align:right;">پایان تمرین خانگی</h2>
#   <p>اگر هر ۱۰ سؤال را خودت کامل کرده باشی، این مهارت‌ها را در عمل دیده‌ای:</p>
#   <ul>
#     <li>ایندکس لیست برای bid و ask، و خواندن کلید دیکشنری برای کوپن</li>
#     <li>باز کردن تاپل برای قیمت کثیف، و <code>split</code> برای سطر تابلو</li>
#     <li><code>max</code> و ایندکس منفی برای قله و NAV امروز</li>
#     <li>تفاوت دفتر دیروز و امروز، و سهم هر دارایی در بازده پرتفوی</li>
#     <li>شکاف سررسید، برابری اختیار، و شاخص تمرکز HHI</li>
#   </ul>
#   <p>اگر جایی گیر کردی، اول راهنمای آبی و کادر سبز همان سؤال را بخوان، بعد فقط همان خط <span class="kbd"># To Do</span> را عوض کن.
#   خروجی را با کادر سبز مقایسه کن؛ فاصله و حروف بزرگ و کوچک مهم‌اند.</p>
# </div>
