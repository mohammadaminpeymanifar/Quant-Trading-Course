# %% [markdown]
# <div class="hero" dir="rtl" align="right" style="direction:rtl;text-align:right;">
#   <h1 style="direction:rtl;text-align:right;">َZero To Quant _ Week 2 _ Cw1</h1>
#   <p>
#     هفته ۲ · جلسه ۱ · ایستگاه اول: پایتون مقدماتی · Zero to Quant<br>
#     <br>
#     هر سؤال یک موقعیت مالی دارد و زیر آن یک سلول کد ناقص است.
#     بخش‌هایی که با <b># To Do</b> مشخص شده‌اند را خودت کامل کن.
#   </p>
#   <div class="hero-meta">
#     <span class="chip">list</span>
#     <span class="chip">dictionary</span>
#     <span class="chip">tuple</span>
#     <span class="chip">set</span>
#     <span class="chip">string</span>
#     <span class="chip">۲۵ سؤال</span>
#   </div>
# </div>

# %% [markdown]
# <div class="guide" dir="rtl" align="right" style="direction:rtl;text-align:right;">
#   <h2 style="direction:rtl;text-align:right;">۰) راهنمای شروع و فونت وزیر</h2>
#   <p>متن سؤال‌ها با فونت <b>وزیرمتن (Vazirmatn)</b> و راست‌چین طراحی شده است.
#   فونت داخل پوشه <span class="kbd">fonts</span> همین پروژه است و نوت‌بوک آن را از همان‌جا فراخوانی می‌کند.</p>
#   <div class="step"><b>مرحله ۱ — اجباری:</b> سلول کد پایین را همین حالا اجرا کن تا فونت و رنگ‌ها اعمال شود.</div>
#   <div class="step"><b>مرحله ۲ — پیشنهادی:</b> اگر می‌خواهی فونت روی کل ویندوز نصب شود، برو به پوشه <span class="kbd">fonts</span> و روی فایل‌های <span class="kbd">.ttf</span> راست‌کلیک کن و <b>Install</b> بزن.
#   راهنمای کامل‌تر داخل <span class="kbd">fonts/راهنمای_نصب_فونت.md</span> است.</div>
#   <div class="step"><b>مرحله ۳:</b> هر سؤال را بخوان، سلول کد زیرش را کامل کن، بعد اجرا کن و با خروجی نمونه مقایسه کن.</div>
#   <p>اگر فونت دیده نشد: مطمئن شو نوت‌بوک را از پوشه‌ای باز کرده‌ای که پوشه <span class="kbd">fonts</span> کنار آن است، بعد همین سلول اول را دوباره Run کن.</p>
# </div>

# %%
# این سلول را اول از همه اجرا کن تا فونت وزیر و استایل سؤال‌ها فعال شود.
from IPython.display import HTML, display
from pathlib import Path

font_dir = Path("fonts")
needed = [
    "Vazirmatn-Regular.woff2",
    "Vazirmatn-Medium.woff2",
    "Vazirmatn-Bold.woff2",
    "notebook_style.html",
]
missing = [name for name in needed if not (font_dir / name).exists()]
if missing:
    print("هشدار: این فایل‌ها پیدا نشد:", ", ".join(missing))
    print("نوت‌بوک را از پوشه پروژه باز کن.")
else:
    print("فونت وزیر از پوشه fonts آماده است.")

style = Path("fonts/notebook_style.html").read_text(encoding="utf-8")
display(HTML(style))
print("استایل و فونت وزیر اعمال شد. حالا سؤال‌ها باید فارسی و رنگی دیده شوند.")

# %% [markdown]
# <div class="help" dir="rtl" align="right" style="direction:rtl;text-align:right;">
#   <h2 style="direction:rtl;text-align:right;">مفاهیم کمکی که ممکن است در بعضی سؤال‌ها ببینی</h2>
#   <p>درس این جلسه همین‌هاست: <code>list</code> · <code>dict</code> · <code>tuple</code> · <code>set</code> · متدهای <code>string</code></p>
#   <ul>
#     <li>لیست: <code>items[0]</code> اول، <code>items[-1]</code> آخر، <code>items[-3:]</code> سه عضو آخر، <code>append</code> اضافه به ته.</li>
#     <li>دیکشنری: <code>d[key]</code> مقدار کلید، <code>d[key] = v</code> نوشتن، <code>d.items()</code> پیمایش جفت‌ها.</li>
#     <li>تاپل: مثل لیست است ولی عوض نمی‌شود. باز کردن: <code>a, b = pair</code>.</li>
#     <li>مجموعه: عضو تکراری ندارد. اشتراک <code>&amp;</code> · اجتماع <code>|</code> · تفاضل <code>-</code>.</li>
#     <li>رشته: <code>upper</code> · <code>strip</code> · <code>split</code> · <code>join</code> · <code>replace</code> · <code>startswith</code> · <code>isdigit</code>.</li>
#     <li><code>sorted(x)</code> یک لیست مرتب‌شده برمی‌گرداند؛ برای چاپ مجموعه از آن استفاده کن تا ترتیب ثابت باشد.</li>
#     <li>از هفته قبل: <code>input</code> · <code>int</code> · <code>if / else</code> · <code>for</code> هنوز این‌جا لازم‌اند.</li>
#   </ul>
# </div>

# %% [markdown]
# <div class="toc" dir="rtl" align="right" style="direction:rtl;text-align:right;">
#   <h2 style="direction:rtl;text-align:right;">فهرست سؤال‌ها</h2>
# </div>
#
# 1. [سؤال ۱ — اولین و آخرین نماد پرتفوی](#q1)
# 2. [سؤال ۲ — قیمت پایانی در تابلو](#q2)
# 3. [سؤال ۳ — باز کردن سفارش تاپلی](#q3)
# 4. [سؤال ۴ — تعداد صنایع یکتا](#q4)
# 5. [سؤال ۵ — استاندارد نماد انگلیسی](#q5)
# 6. [سؤال ۶ — پاک‌سازی کد ISIN](#q6)
# 7. [سؤال ۷ — شمارش سفارش‌های خرید](#q7)
# 8. [سؤال ۸ — شکستن تیکر بلومبرگ](#q8)
# 9. [سؤال ۹ — اوراق داخلی یا خارجی](#q9)
# 10. [سؤال ۱۰ — گزارش یک‌خطی نمادها](#q10)
# 11. [سؤال ۱۱ — افزودن سهم به واچ‌لیست](#q11)
# 12. [سؤال ۱۲ — مومنتوم سه روزه](#q12)
# 13. [سؤال ۱۳ — به‌روزرسانی NAV صندوق](#q13)
# 14. [سؤال ۱۴ — سهام مشترک دو صندوق](#q14)
# 15. [سؤال ۱۵ — خواندن قیمت از متن تابلو](#q15)
# 16. [سؤال ۱۶ — ماه پرداخت کوپن](#q16)
# 17. [سؤال ۱۷ — فیلتر سمت خرید در بلاتر](#q17)
# 18. [سؤال ۱۸ — نرمال‌سازی جفت‌ارز](#q18)
# 19. [سؤال ۱۹ — طرف‌های معامله یکتا](#q19)
# 20. [سؤال ۲۰ — پروفایل اعتباری مشتری](#q20)
# 21. [سؤال ۲۱ — گروه‌بندی پرتفوی بر اساس صنعت](#q21)
# 22. [سؤال ۲۲ — وزن بیش از حد نسبت به هدف](#q22)
# 23. [سؤال ۲۳ — تبدیل رشته بلاتر به سفارش](#q23)
# 24. [سؤال ۲۴ — ساخت جهان سرمایه‌گذاری](#q24)
# 25. [سؤال ۲۵ — اعتبارسنجی شبا و کد بانک](#q25)

# %% [markdown]
# ###### q1
#
# <div class="qcard" dir="rtl" align="right" style="direction:rtl;text-align:right;">
#   <div class="qbar" dir="rtl" style="direction:rtl;text-align:right;">
#     <span class="qnum">سؤال ۱</span>
#     <span class="tags">list · indexing</span>
#   </div>
#   <h2 style="direction:rtl;text-align:right;">اولین و آخرین نماد پرتفوی</h2>
#   <div class="qbody" dir="rtl" style="direction:rtl;text-align:right;">لیست نمادهای پرتفوی آماده است. در میز معاملات معمولاً اول و آخر لیست را برای کنترل سریع نگاه می‌کنند. اولین نماد و آخرین نماد را هر کدام در یک خط چاپ کن.</div>
#   <div class="box tip" dir="rtl"><b>راهنما:</b> ایندکس <code>0</code> اولین عضو است. ایندکس <code>-1</code> از ته لیست می‌شمارد و آخرین عضو را می‌دهد.</div>
#
#   <div class="io">
#     <div class="pane in">
#       <div class="pane-label">ورودی نمونه</div>
#       <pre dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate;white-space:pre;">این سؤال ورودی ندارد</pre>
#     </div>
#     <div class="pane out">
#       <div class="pane-label">خروجی نمونه</div>
#       <pre dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate;white-space:pre;">FOOLAD
# MAPNA</pre>
#     </div>
#   </div>
#   <div class="box why" dir="rtl"><b>چرا این خروجی؟</b> چهار نماد در لیست است. اولی فولاد و آخری مپنا است؛ پس همین دو خط چاپ می‌شود.</div>
# </div>

# %%
holdings = ["FOOLAD", "SHPNA", "KHODRO", "MAPNA"]

# To Do: اولین نماد را چاپ کن
# To Do: آخرین نماد را چاپ کن

# %% [markdown]
# ###### q2
#
# <div class="qcard" dir="rtl" align="right" style="direction:rtl;text-align:right;">
#   <div class="qbar" dir="rtl" style="direction:rtl;text-align:right;">
#     <span class="qnum">سؤال ۲</span>
#     <span class="tags">dict · indexing</span>
#   </div>
#   <h2 style="direction:rtl;text-align:right;">قیمت پایانی در تابلو</h2>
#   <div class="qbody" dir="rtl" style="direction:rtl;text-align:right;">تابلوی قیمت پایانی یک دیکشنری است: کلید نماد و مقدار قیمت. نماد را از ورودی بگیر و قیمت پایانی‌اش را چاپ کن.</div>
#   <div class="box tip" dir="rtl"><b>راهنما:</b> مقدار متناظر با کلید <code>k</code> را با <code>prices[k]</code> می‌گیری.</div>
#
#   <div class="io">
#     <div class="pane in">
#       <div class="pane-label">ورودی نمونه</div>
#       <pre dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate;white-space:pre;">SHPNA</pre>
#     </div>
#     <div class="pane out">
#       <div class="pane-label">خروجی نمونه</div>
#       <pre dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate;white-space:pre;">1850</pre>
#     </div>
#   </div>
#   <div class="box why" dir="rtl"><b>چرا این خروجی؟</b> کلید SHPNA در تابلو مقدار ۱۸۵۰ دارد؛ پس همان عدد چاپ می‌شود.</div>
# </div>

# %%
prices = {"FOOLAD": 720, "SHPNA": 1850, "MAPNA": 410}
ticker = input()

# To Do: قیمت ticker را از دیکشنری چاپ کن

# %% [markdown]
# ###### q3
#
# <div class="qcard" dir="rtl" align="right" style="direction:rtl;text-align:right;">
#   <div class="qbar" dir="rtl" style="direction:rtl;text-align:right;">
#     <span class="qnum">سؤال ۳</span>
#     <span class="tags">tuple · unpack</span>
#   </div>
#   <h2 style="direction:rtl;text-align:right;">باز کردن سفارش تاپلی</h2>
#   <div class="qbody" dir="rtl" style="direction:rtl;text-align:right;">هر سفارش در سامانه به‌صورت یک تاپل ثابت ذخیره می‌شود: سمت، نماد، حجم، قیمت. تاپل را باز کن و یک خط به شکل <code>SIDE QTY TICKER @ PRICE</code> چاپ کن.</div>
#   <div class="box tip" dir="rtl"><b>راهنما:</b> می‌توانی بنویسی <code>side, ticker, qty, price = order</code> تا چهار متغیر یک‌جا مقدار بگیرند.</div>
#   <div class="box extra" dir="rtl"><b>راهنمای مفهوم کمکی:</b> تاپل بعد از ساخته‌شدن عوض نمی‌شود؛ برای سندی مثل سفارش که نباید وسط کار تغییر کند مناسب است.</div>
#   <div class="io">
#     <div class="pane in">
#       <div class="pane-label">ورودی نمونه</div>
#       <pre dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate;white-space:pre;">این سؤال ورودی ندارد</pre>
#     </div>
#     <div class="pane out">
#       <div class="pane-label">خروجی نمونه</div>
#       <pre dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate;white-space:pre;">BUY 1000 FOOLAD @ 720</pre>
#     </div>
#   </div>
#   <div class="box why" dir="rtl"><b>چرا این خروجی؟</b> چهار مقدار تاپل به‌ترتیب BUY، FOOLAD، ۱۰۰۰ و ۷۲۰ هستند. حجم قبل از نماد در قالب گزارش می‌آید.</div>
# </div>

# %%
order = ("BUY", "FOOLAD", 1000, 720)

# To Do: تاپل را باز کن و خط گزارش را چاپ کن

# %% [markdown]
# ###### q4
#
# <div class="qcard" dir="rtl" align="right" style="direction:rtl;text-align:right;">
#   <div class="qbar" dir="rtl" style="direction:rtl;text-align:right;">
#     <span class="qnum">سؤال ۴</span>
#     <span class="tags">set · len</span>
#   </div>
#   <h2 style="direction:rtl;text-align:right;">تعداد صنایع یکتا</h2>
#   <div class="qbody" dir="rtl" style="direction:rtl;text-align:right;">لیست صنعت هر موقعیت پرتفوی داده شده است. بعضی صنایع تکرار شده‌اند. برای گزارش تمرکز صنعتی، تعداد صنایع <b>یکتا</b> را چاپ کن.</div>
#   <div class="box tip" dir="rtl"><b>راهنما:</b> از لیست یک <code>set</code> بساز؛ عضو تکراری در مجموعه نمی‌ماند. بعد <code>len</code> بگیر.</div>
#   <div class="box extra" dir="rtl"><b>راهنمای مفهوم کمکی:</b> <code>set(list)</code> فقط مقدارهای متمایز را نگه می‌دارد.</div>
#   <div class="io">
#     <div class="pane in">
#       <div class="pane-label">ورودی نمونه</div>
#       <pre dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate;white-space:pre;">این سؤال ورودی ندارد</pre>
#     </div>
#     <div class="pane out">
#       <div class="pane-label">خروجی نمونه</div>
#       <pre dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate;white-space:pre;">3</pre>
#     </div>
#   </div>
#   <div class="box why" dir="rtl"><b>چرا این خروجی؟</b> بانک سه بار، فلزات دو بار و پتروشیمی یک بار آمده؛ سه صنعت متمایز می‌ماند.</div>
# </div>

# %%
sectors = ["بانک", "فلزات", "بانک", "پتروشیمی", "فلزات", "بانک"]

# To Do: تعداد صنایع یکتا را چاپ کن

# %% [markdown]
# ###### q5
#
# <div class="qcard" dir="rtl" align="right" style="direction:rtl;text-align:right;">
#   <div class="qbar" dir="rtl" style="direction:rtl;text-align:right;">
#     <span class="qnum">سؤال ۵</span>
#     <span class="tags">string · upper</span>
#   </div>
#   <h2 style="direction:rtl;text-align:right;">استاندارد نماد انگلیسی</h2>
#   <div class="qbody" dir="rtl" style="direction:rtl;text-align:right;">نماد را از ورودی بگیر و برای ثبت در سامانه به حروف بزرگ انگلیسی تبدیل کن. سامانه تسویه نماد کوچک و بزرگ را یکی نمی‌داند؛ باید استاندارد شود.</div>
#   <div class="box tip" dir="rtl"><b>راهنما:</b> متد <code>s.upper()</code> همه حرف‌های متن را بزرگ می‌کند.</div>
#
#   <div class="io">
#     <div class="pane in">
#       <div class="pane-label">ورودی نمونه</div>
#       <pre dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate;white-space:pre;">foolad</pre>
#     </div>
#     <div class="pane out">
#       <div class="pane-label">خروجی نمونه</div>
#       <pre dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate;white-space:pre;">FOOLAD</pre>
#     </div>
#   </div>
#   <div class="box why" dir="rtl"><b>چرا این خروجی؟</b> ورودی foolad است؛ بعد از upper دقیقاً FOOLAD می‌شود.</div>
# </div>

# %%
ticker = input()

# To Do: نسخه حروف‌بزرگ ticker را چاپ کن

# %% [markdown]
# ###### q6
#
# <div class="qcard" dir="rtl" align="right" style="direction:rtl;text-align:right;">
#   <div class="qbar" dir="rtl" style="direction:rtl;text-align:right;">
#     <span class="qnum">سؤال ۶</span>
#     <span class="tags">string · strip</span>
#   </div>
#   <h2 style="direction:rtl;text-align:right;">پاک‌سازی کد ISIN</h2>
#   <div class="qbody" dir="rtl" style="direction:rtl;text-align:right;">کد ISIN از فایل اکسل آمده و دو طرفش فاصله اضافه دارد. فاصله‌های اول و آخر را حذف کن و کد تمیز را چاپ کن. فاصله وسط را دست نزن.</div>
#   <div class="box tip" dir="rtl"><b>راهنما:</b> <code>s.strip()</code> فقط فاصله و خط جدید دو سر رشته را برمی‌دارد.</div>
#
#   <div class="io">
#     <div class="pane in">
#       <div class="pane-label">ورودی نمونه</div>
#       <pre dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate;white-space:pre;">این سؤال ورودی ندارد</pre>
#     </div>
#     <div class="pane out">
#       <div class="pane-label">خروجی نمونه</div>
#       <pre dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate;white-space:pre;">IRX0A0000001</pre>
#     </div>
#   </div>
#   <div class="box why" dir="rtl"><b>چرا این خروجی؟</b> متن داخل متغیر با فاصله شروع و تمام می‌شود؛ strip آن فاصله‌ها را حذف می‌کند و خود ISIN می‌ماند.</div>
# </div>

# %%
isin = "  IRX0A0000001  "

# To Do: فاصله‌های دو سر را حذف کن و چاپ کن

# %% [markdown]
# ###### q7
#
# <div class="qcard" dir="rtl" align="right" style="direction:rtl;text-align:right;">
#   <div class="qbar" dir="rtl" style="direction:rtl;text-align:right;">
#     <span class="qnum">سؤال ۷</span>
#     <span class="tags">list · count</span>
#   </div>
#   <h2 style="direction:rtl;text-align:right;">شمارش سفارش‌های خرید</h2>
#   <div class="qbody" dir="rtl" style="direction:rtl;text-align:right;">لیست سمت سفارش‌های امروز میز داده شده است. برای گزارش جریان سفارش، تعداد سفارش‌های <code>BUY</code> را چاپ کن.</div>
#   <div class="box tip" dir="rtl"><b>راهنما:</b> <code>items.count(x)</code> می‌گوید x چند بار در لیست آمده است.</div>
#
#   <div class="io">
#     <div class="pane in">
#       <div class="pane-label">ورودی نمونه</div>
#       <pre dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate;white-space:pre;">این سؤال ورودی ندارد</pre>
#     </div>
#     <div class="pane out">
#       <div class="pane-label">خروجی نمونه</div>
#       <pre dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate;white-space:pre;">3</pre>
#     </div>
#   </div>
#   <div class="box why" dir="rtl"><b>چرا این خروجی؟</b> پنج سفارش هست: سه تا BUY و دو تا SELL. جواب ۳ است.</div>
# </div>

# %%
sides = ["BUY", "SELL", "BUY", "BUY", "SELL"]

# To Do: تعداد BUY را چاپ کن

# %% [markdown]
# ###### q8
#
# <div class="qcard" dir="rtl" align="right" style="direction:rtl;text-align:right;">
#   <div class="qbar" dir="rtl" style="direction:rtl;text-align:right;">
#     <span class="qnum">سؤال ۸</span>
#     <span class="tags">string · split</span>
#   </div>
#   <h2 style="direction:rtl;text-align:right;">شکستن تیکر بلومبرگ</h2>
#   <div class="qbody" dir="rtl" style="direction:rtl;text-align:right;">تیکر بلومبرگ سه بخش دارد که با فاصله جدا شده‌اند: نماد، کد بازار، نوع ورقه. متن را بگیر، به سه بخش بشکن و هر بخش را در یک خط چاپ کن.</div>
#   <div class="box tip" dir="rtl"><b>راهنما:</b> <code>s.split()</code> متن را از روی فاصله به لیست واژه‌ها تبدیل می‌کند. بعد هر واژه را چاپ کن.</div>
#
#   <div class="io">
#     <div class="pane in">
#       <div class="pane-label">ورودی نمونه</div>
#       <pre dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate;white-space:pre;">MSFT US Equity</pre>
#     </div>
#     <div class="pane out">
#       <div class="pane-label">خروجی نمونه</div>
#       <pre dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate;white-space:pre;">MSFT
# US
# Equity</pre>
#     </div>
#   </div>
#   <div class="box why" dir="rtl"><b>چرا این خروجی؟</b> سه واژه MSFT و US و Equity است؛ هر کدام یک خط می‌شوند.</div>
# </div>

# %%
ticker = input()

# To Do: ticker را split کن و هر بخش را در یک خط چاپ کن

# %% [markdown]
# ###### q9
#
# <div class="qcard" dir="rtl" align="right" style="direction:rtl;text-align:right;">
#   <div class="qbar" dir="rtl" style="direction:rtl;text-align:right;">
#     <span class="qnum">سؤال ۹</span>
#     <span class="tags">string · startswith</span>
#   </div>
#   <h2 style="direction:rtl;text-align:right;">اوراق داخلی یا خارجی</h2>
#   <div class="qbody" dir="rtl" style="direction:rtl;text-align:right;">کد ISIN را بگیر. اگر با <code>IR</code> شروع شود ورقه داخلی است و <code>Domestic</code> چاپ کن؛ وگرنه <code>Foreign</code>.</div>
#   <div class="box tip" dir="rtl"><b>راهنما:</b> <code>s.startswith("IR")</code> بررسی می‌کند متن با IR شروع می‌شود یا نه.</div>
#
#   <div class="io">
#     <div class="pane in">
#       <div class="pane-label">ورودی نمونه</div>
#       <pre dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate;white-space:pre;">IRX0A0000001</pre>
#     </div>
#     <div class="pane out">
#       <div class="pane-label">خروجی نمونه</div>
#       <pre dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate;white-space:pre;">Domestic</pre>
#     </div>
#   </div>
#   <div class="box why" dir="rtl"><b>چرا این خروجی؟</b> نمونه با IR شروع می‌شود؛ پس داخلی است و Domestic چاپ می‌شود.</div>
# </div>

# %%
isin = input()

# To Do: با if تصمیم بگیر Domestic یا Foreign

# %% [markdown]
# ###### q10
#
# <div class="qcard" dir="rtl" align="right" style="direction:rtl;text-align:right;">
#   <div class="qbar" dir="rtl" style="direction:rtl;text-align:right;">
#     <span class="qnum">سؤال ۱۰</span>
#     <span class="tags">list · join</span>
#   </div>
#   <h2 style="direction:rtl;text-align:right;">گزارش یک‌خطی نمادها</h2>
#   <div class="qbody" dir="rtl" style="direction:rtl;text-align:right;">لیست نمادهای پرتفوی را به یک رشته گزارش تبدیل کن تا در پیامک شعبه برود. نمادها باید با <code> | </code> به هم بچسبند (فاصله، خط عمودی، فاصله).</div>
#   <div class="box tip" dir="rtl"><b>راهنما:</b> <code>" | ".join(tickers)</code> اعضای لیست را با همان جداکننده به یک متن تبدیل می‌کند.</div>
#   <div class="box extra" dir="rtl"><b>راهنمای مفهوم کمکی:</b> برعکس <code>split</code> است: split متن را به لیست می‌کند، join لیست را به متن.</div>
#   <div class="io">
#     <div class="pane in">
#       <div class="pane-label">ورودی نمونه</div>
#       <pre dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate;white-space:pre;">این سؤال ورودی ندارد</pre>
#     </div>
#     <div class="pane out">
#       <div class="pane-label">خروجی نمونه</div>
#       <pre dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate;white-space:pre;">FOOLAD | SHPNA | MAPNA</pre>
#     </div>
#   </div>
#   <div class="box why" dir="rtl"><b>چرا این خروجی؟</b> سه نماد با جداکننده مشخص به یک خط تبدیل می‌شوند؛ قبل از اولی و بعد از آخری | نمی‌آید.</div>
# </div>

# %%
tickers = ["FOOLAD", "SHPNA", "MAPNA"]

# To Do: نمادها را با جداکننده « | » بچسبان و چاپ کن

# %% [markdown]
# ###### q11
#
# <div class="qcard" dir="rtl" align="right" style="direction:rtl;text-align:right;">
#   <div class="qbar" dir="rtl" style="direction:rtl;text-align:right;">
#     <span class="qnum">سؤال ۱۱</span>
#     <span class="tags">list · append</span>
#   </div>
#   <h2 style="direction:rtl;text-align:right;">افزودن سهم به واچ‌لیست</h2>
#   <div class="qbody" dir="rtl" style="direction:rtl;text-align:right;">واچ‌لیست تحلیل‌گر دو نماد دارد. نماد جدید را از ورودی بگیر، به انتهای لیست اضافه کن، بعد کل واچ‌لیست را با فاصله در یک خط چاپ کن.</div>
#   <div class="box tip" dir="rtl"><b>راهنما:</b> <code>watch.append(x)</code> عضو را به ته لیست اضافه می‌کند. برای چاپ یک‌خطی از <code>join</code> با فاصله استفاده کن.</div>
#
#   <div class="io">
#     <div class="pane in">
#       <div class="pane-label">ورودی نمونه</div>
#       <pre dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate;white-space:pre;">MAPNA</pre>
#     </div>
#     <div class="pane out">
#       <div class="pane-label">خروجی نمونه</div>
#       <pre dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate;white-space:pre;">FOOLAD SHPNA MAPNA</pre>
#     </div>
#   </div>
#   <div class="box why" dir="rtl"><b>چرا این خروجی؟</b> اول فولاد و شپنا بودند؛ مپنا به ته لیست اضافه شد و سه نماد با فاصله چاپ می‌شوند.</div>
# </div>

# %%
watch = ["FOOLAD", "SHPNA"]
new_ticker = input()

# To Do: new_ticker را به واچ‌لیست اضافه کن
# To Do: همه نمادها را با فاصله در یک خط چاپ کن

# %% [markdown]
# ###### q12
#
# <div class="qcard" dir="rtl" align="right" style="direction:rtl;text-align:right;">
#   <div class="qbar" dir="rtl" style="direction:rtl;text-align:right;">
#     <span class="qnum">سؤال ۱۲</span>
#     <span class="tags">list · slicing</span>
#   </div>
#   <h2 style="direction:rtl;text-align:right;">مومنتوم سه روزه</h2>
#   <div class="qbody" dir="rtl" style="direction:rtl;text-align:right;">بازده روزانه یک سهم (درصد) در یک لیست آمده است؛ ایندکس صفر یعنی قدیمی‌ترین روز. مومنتوم کوتاه‌مدت را مجموع <b>سه روز آخر</b> بگیر و چاپ کن.</div>
#   <div class="box tip" dir="rtl"><b>راهنما:</b> برش <code>rets[-3:]</code> سه عضو آخر را می‌دهد. <code>sum</code> همان‌ها را جمع می‌کند.</div>
#   <div class="box extra" dir="rtl"><b>راهنمای مفهوم کمکی:</b> در پایتون <code>a[start:end]</code> از start تا قبل از end را برمی‌دارد. ایندکس منفی از ته لیست می‌شمارد.</div>
#   <div class="io">
#     <div class="pane in">
#       <div class="pane-label">ورودی نمونه</div>
#       <pre dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate;white-space:pre;">این سؤال ورودی ندارد</pre>
#     </div>
#     <div class="pane out">
#       <div class="pane-label">خروجی نمونه</div>
#       <pre dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate;white-space:pre;">3</pre>
#     </div>
#   </div>
#   <div class="box why" dir="rtl"><b>چرا این خروجی؟</b> لیست شش روزه است. سه روز آخر ۰ و ۴ و ۱− هستند؛ ۰+۴+(−۱)=۳.</div>
# </div>

# %%
rets = [2, -1, 3, 0, 4, -1]

# To Do: مجموع سه بازده آخر را چاپ کن

# %% [markdown]
# ###### q13
#
# <div class="qcard" dir="rtl" align="right" style="direction:rtl;text-align:right;">
#   <div class="qbar" dir="rtl" style="direction:rtl;text-align:right;">
#     <span class="qnum">سؤال ۱۳</span>
#     <span class="tags">dict · update</span>
#   </div>
#   <h2 style="direction:rtl;text-align:right;">به‌روزرسانی NAV صندوق</h2>
#   <div class="qbody" dir="rtl" style="direction:rtl;text-align:right;">NAV سه صندوق در یک دیکشنری است. نام صندوق و NAV جدید را بگیر، همان کلید را به‌روز کن، بعد برای هر صندوق یک خط <code>name value</code> چاپ کن (ترتیب همان ترتیب دیکشنری).</div>
#   <div class="box tip" dir="rtl"><b>راهنما:</b> نوشتن <code>nav[name] = new_val</code> اگر کلید از قبل باشد مقدار را عوض می‌کند. برای پیمایش از <code>nav.items()</code> استفاده کن.</div>
#
#   <div class="io">
#     <div class="pane in">
#       <div class="pane-label">ورودی نمونه</div>
#       <pre dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate;white-space:pre;">Growth
# 2700</pre>
#     </div>
#     <div class="pane out">
#       <div class="pane-label">خروجی نمونه</div>
#       <pre dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate;white-space:pre;">Income 1000
# Growth 2700
# Balanced 1800</pre>
#     </div>
#   </div>
#   <div class="box why" dir="rtl"><b>چرا این خروجی؟</b> فقط صندوق Growth از ۲۵۰۰ به ۲۷۰۰ می‌رسد. درآمد و متوازن دست‌نخورده می‌مانند.</div>
# </div>

# %%
nav = {"Income": 1000, "Growth": 2500, "Balanced": 1800}
name = input()
new_val = int(input())

# To Do: NAV صندوق name را عوض کن
# To Do: همه صندوق‌ها را چاپ کن

# %% [markdown]
# ###### q14
#
# <div class="qcard" dir="rtl" align="right" style="direction:rtl;text-align:right;">
#   <div class="qbar" dir="rtl" style="direction:rtl;text-align:right;">
#     <span class="qnum">سؤال ۱۴</span>
#     <span class="tags">set · intersection</span>
#   </div>
#   <h2 style="direction:rtl;text-align:right;">سهام مشترک دو صندوق</h2>
#   <div class="qbody" dir="rtl" style="direction:rtl;text-align:right;">هلدینگ دو صندوق را در دو خط می‌گیری (نمادها با فاصله). سهام مشترک یعنی جایی که هر دو صندوق روی یک نام شرط بسته‌اند؛ تمرکز ریسک اینجاست. اشتراک را به‌صورت الفبایی و با فاصله در یک خط چاپ کن.</div>
#   <div class="box tip" dir="rtl"><b>راهنما:</b> هر خط را <code>split</code> کن و <code>set</code> بساز. اشتراک دو مجموعه با <code>a &amp; b</code> به‌دست می‌آید. قبل از چاپ <code>sorted</code> کن تا ترتیب ثابت باشد.</div>
#   <div class="box extra" dir="rtl"><b>راهنمای مفهوم کمکی:</b> <code>sorted(s)</code> از مجموعه یک لیست مرتب می‌سازد. اجتماع <code>|</code> و تفاضل <code>-</code> است.</div>
#   <div class="io">
#     <div class="pane in">
#       <div class="pane-label">ورودی نمونه</div>
#       <pre dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate;white-space:pre;">FOOLAD SHPNA MAPNA KHODRO
# SHPNA MAPNA TAPIC</pre>
#     </div>
#     <div class="pane out">
#       <div class="pane-label">خروجی نمونه</div>
#       <pre dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate;white-space:pre;">MAPNA SHPNA</pre>
#     </div>
#   </div>
#   <div class="box why" dir="rtl"><b>چرا این خروجی؟</b> شپنا و مپنا در هر دو خط هستند. فولاد و خودرو فقط در اولی‌اند و تاپیکو فقط در دومی. خروجی الفبایی می‌شود MAPNA سپس SHPNA.</div>
# </div>

# %%
line1 = input()
line2 = input()

# To Do: دو مجموعه بساز، اشتراک را بگیر، مرتب چاپ کن

# %% [markdown]
# ###### q15
#
# <div class="qcard" dir="rtl" align="right" style="direction:rtl;text-align:right;">
#   <div class="qbar" dir="rtl" style="direction:rtl;text-align:right;">
#     <span class="qnum">سؤال ۱۵</span>
#     <span class="tags">string · split</span>
#   </div>
#   <h2 style="direction:rtl;text-align:right;">خواندن قیمت از متن تابلو</h2>
#   <div class="qbody" dir="rtl" style="direction:rtl;text-align:right;">یک خط از ترمینال بازار به شکل <code>TICKER:PRICE</code> می‌آید. نماد، قیمت، و ارزش ۱۰ سهم (قیمت × ۱۰) را هر کدام در یک خط چاپ کن.</div>
#   <div class="box tip" dir="rtl"><b>راهنما:</b> با <code>split(":")</code> دو بخش بساز. بخش دوم هنوز متن است؛ با <code>int</code> عددش کن.</div>
#
#   <div class="io">
#     <div class="pane in">
#       <div class="pane-label">ورودی نمونه</div>
#       <pre dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate;white-space:pre;">FOOLAD:720</pre>
#     </div>
#     <div class="pane out">
#       <div class="pane-label">خروجی نمونه</div>
#       <pre dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate;white-space:pre;">FOOLAD
# 720
# 7200</pre>
#     </div>
#   </div>
#   <div class="box why" dir="rtl"><b>چرا این خروجی؟</b> نماد فولاد و قیمت ۷۲۰ است. ده سهم ۷۲۰۰ می‌ارزد.</div>
# </div>

# %%
text = input()

# To Do: نماد و قیمت را جدا کن، بعد ارزش ۱۰ سهم را هم چاپ کن

# %% [markdown]
# ###### q16
#
# <div class="qcard" dir="rtl" align="right" style="direction:rtl;text-align:right;">
#   <div class="qbar" dir="rtl" style="direction:rtl;text-align:right;">
#     <span class="qnum">سؤال ۱۶</span>
#     <span class="tags">tuple · in</span>
#   </div>
#   <h2 style="direction:rtl;text-align:right;">ماه پرداخت کوپن</h2>
#   <div class="qbody" dir="rtl" style="direction:rtl;text-align:right;">اوراق کوپن را در ماه‌های ۳، ۶، ۹ و ۱۲ پرداخت می‌کند. این تقویم یک تاپل ثابت است. شماره ماه را بگیر؛ اگر ماه کوپن بود <code>Coupon</code> وگرنه <code>None</code> چاپ کن.</div>
#   <div class="box tip" dir="rtl"><b>راهنما:</b> عضویت را با <code>m in coupons</code> چک کن. تاپل برای تقویمی که نباید عوض شود بهتر از لیست است.</div>
#
#   <div class="io">
#     <div class="pane in">
#       <div class="pane-label">ورودی نمونه</div>
#       <pre dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate;white-space:pre;">6</pre>
#     </div>
#     <div class="pane out">
#       <div class="pane-label">خروجی نمونه</div>
#       <pre dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate;white-space:pre;">Coupon</pre>
#     </div>
#   </div>
#   <div class="box why" dir="rtl"><b>چرا این خروجی؟</b> ۶ داخل (۳، ۶، ۹، ۱۲) هست؛ پس آن ماه کوپن دارد.</div>
# </div>

# %%
coupons = (3, 6, 9, 12)
month = int(input())

# To Do: اگر month داخل coupons بود Coupon وگرنه None چاپ کن

# %% [markdown]
# ###### q17
#
# <div class="qcard" dir="rtl" align="right" style="direction:rtl;text-align:right;">
#   <div class="qbar" dir="rtl" style="direction:rtl;text-align:right;">
#     <span class="qnum">سؤال ۱۷</span>
#     <span class="tags">list · tuple · for</span>
#   </div>
#   <h2 style="direction:rtl;text-align:right;">فیلتر سمت خرید در بلاتر</h2>
#   <div class="qbody" dir="rtl" style="direction:rtl;text-align:right;">بلاتر امروز لیستی از تاپل‌های <code>(side, ticker, qty)</code> است. فقط سفارش‌های خرید را برای میز اجرا گزارش کن: هر خرید یک خط <code>ticker qty</code>.</div>
#   <div class="box tip" dir="rtl"><b>راهنما:</b> روی لیست حلقه بزن، تاپل را باز کن، و فقط وقتی <code>side == "BUY"</code> بود چاپ کن.</div>
#
#   <div class="io">
#     <div class="pane in">
#       <div class="pane-label">ورودی نمونه</div>
#       <pre dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate;white-space:pre;">این سؤال ورودی ندارد</pre>
#     </div>
#     <div class="pane out">
#       <div class="pane-label">خروجی نمونه</div>
#       <pre dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate;white-space:pre;">FOOLAD 100
# MAPNA 200</pre>
#     </div>
#   </div>
#   <div class="box why" dir="rtl"><b>چرا این خروجی؟</b> چهار سفارش هست. دو تا SELL حذف می‌شوند. خریدها فولاد ۱۰۰ و مپنا ۲۰۰ هستند.</div>
# </div>

# %%
orders = [
    ("BUY", "FOOLAD", 100),
    ("SELL", "SHPNA", 50),
    ("BUY", "MAPNA", 200),
    ("SELL", "FOOLAD", 30),
]

# To Do: فقط سفارش‌های BUY را چاپ کن
for item in orders:
    side, ticker, qty = item
    # To Do: شرط سمت خرید

# %% [markdown]
# ###### q18
#
# <div class="qcard" dir="rtl" align="right" style="direction:rtl;text-align:right;">
#   <div class="qbar" dir="rtl" style="direction:rtl;text-align:right;">
#     <span class="qnum">سؤال ۱۸</span>
#     <span class="tags">string · replace · upper</span>
#   </div>
#   <h2 style="direction:rtl;text-align:right;">نرمال‌سازی جفت‌ارز</h2>
#   <div class="qbody" dir="rtl" style="direction:rtl;text-align:right;">جفت‌ارز را از ورودی بگیر و برای ثبت در سیستم به قالب استاندارد تبدیل کن: فاصله‌های دو سر حذف، حروف بزرگ، و حذف کاراکتر <code>/</code>. مثلاً usd/irr بشود USDIRR.</div>
#   <div class="box tip" dir="rtl"><b>راهنما:</b> می‌توانی متدها را زنجیره کنی: <code>s.strip().upper().replace("/", "")</code></div>
#
#   <div class="io">
#     <div class="pane in">
#       <div class="pane-label">ورودی نمونه</div>
#       <pre dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate;white-space:pre;">usd/irr</pre>
#     </div>
#     <div class="pane out">
#       <div class="pane-label">خروجی نمونه</div>
#       <pre dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate;white-space:pre;">USDIRR</pre>
#     </div>
#   </div>
#   <div class="box why" dir="rtl"><b>چرا این خروجی؟</b> اول حروف بزرگ می‌شود USD/IRR و بعد اسلش حذف می‌شود؛ می‌ماند USDIRR.</div>
# </div>

# %%
pair = input()

# To Do: قالب استاندارد جفت‌ارز را بساز و چاپ کن

# %% [markdown]
# ###### q19
#
# <div class="qcard" dir="rtl" align="right" style="direction:rtl;text-align:right;">
#   <div class="qbar" dir="rtl" style="direction:rtl;text-align:right;">
#     <span class="qnum">سؤال ۱۹</span>
#     <span class="tags">set · sorted</span>
#   </div>
#   <h2 style="direction:rtl;text-align:right;">طرف‌های معامله یکتا</h2>
#   <div class="qbody" dir="rtl" style="direction:rtl;text-align:right;">نام طرف‌های معامله امروز در یک خط با فاصله آمده و بعضی تکرار شده‌اند. برای گزارش تمرکز طرف‌حساب، اول تعداد نام‌های یکتا و در خط بعد همان نام‌ها را الفبایی با فاصله چاپ کن.</div>
#   <div class="box tip" dir="rtl"><b>راهنما:</b> لیست را به <code>set</code> تبدیل کن تا تکرار حذف شود. تعداد با <code>len</code> و ترتیب با <code>sorted</code>.</div>
#
#   <div class="io">
#     <div class="pane in">
#       <div class="pane-label">ورودی نمونه</div>
#       <pre dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate;white-space:pre;">Mellat Saderat Mellat Pasargad Saderat Tejarat</pre>
#     </div>
#     <div class="pane out">
#       <div class="pane-label">خروجی نمونه</div>
#       <pre dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate;white-space:pre;">4
# Mellat Pasargad Saderat Tejarat</pre>
#     </div>
#   </div>
#   <div class="box why" dir="rtl"><b>چرا این خروجی؟</b> ملت و صادرات تکرار شده‌اند. چهار بانک متمایز می‌ماند: ملت، پاسارگاد، صادرات، تجارت — به‌ترتیب الفبا.</div>
# </div>

# %%
names = input().split()

# To Do: تعداد یکتا و لیست مرتب را چاپ کن

# %% [markdown]
# ###### q20
#
# <div class="qcard" dir="rtl" align="right" style="direction:rtl;text-align:right;">
#   <div class="qbar" dir="rtl" style="direction:rtl;text-align:right;">
#     <span class="qnum">سؤال ۲۰</span>
#     <span class="tags">dict · nested</span>
#   </div>
#   <h2 style="direction:rtl;text-align:right;">پروفایل اعتباری مشتری</h2>
#   <div class="qbody" dir="rtl" style="direction:rtl;text-align:right;">پرونده اعتباری مشتری یک دیکشنری تو در تو است: برای هر نام، موجودی و رتبه و سقف اعتبار جداگانه نگه داشته شده. نام مشتری و نام فیلد را بگیر و همان مقدار را چاپ کن.</div>
#   <div class="box tip" dir="rtl"><b>راهنما:</b> دسترسی تو در تو یعنی <code>clients[name][field]</code>. اول مشتری را بردار، بعد فیلد داخل پرونده‌اش را.</div>
#   <div class="box extra" dir="rtl"><b>راهنمای مفهوم کمکی:</b> دیکشنری می‌تواند مقدارش خودش یک دیکشنری دیگر باشد. این مدل برای پروفایل مشتری رایج است.</div>
#   <div class="io">
#     <div class="pane in">
#       <div class="pane-label">ورودی نمونه</div>
#       <pre dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate;white-space:pre;">sara
# rating</pre>
#     </div>
#     <div class="pane out">
#       <div class="pane-label">خروجی نمونه</div>
#       <pre dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate;white-space:pre;">AA</pre>
#     </div>
#   </div>
#   <div class="box why" dir="rtl"><b>چرا این خروجی؟</b> مشتری sara انتخاب شده و فیلد rating مقدار AA دارد.</div>
# </div>

# %%
clients = {
    "sara": {"balance": 120, "rating": "AA", "limit": 50},
    "ali": {"balance": 80, "rating": "BBB", "limit": 20},
}
name = input()
field = input()

# To Do: مقدار فیلد خواسته‌شده را چاپ کن

# %% [markdown]
# ###### q21
#
# <div class="qcard" dir="rtl" align="right" style="direction:rtl;text-align:right;">
#   <div class="qbar" dir="rtl" style="direction:rtl;text-align:right;">
#     <span class="qnum">سؤال ۲۱</span>
#     <span class="tags">dict · list · for</span>
#   </div>
#   <h2 style="direction:rtl;text-align:right;">گروه‌بندی پرتفوی بر اساس صنعت</h2>
#   <div class="qbody" dir="rtl" style="direction:rtl;text-align:right;">برای گزارش ریسک صنعت، باید پرتفوی را گروه‌بندی کنی. اول n را بگیر، بعد n خط <code>TICKER SECTOR</code>. یک دیکشنری بساز که کلیدش صنعت و مقدارش لیست نمادهای همان صنعت باشد. هر صنعت را به ترتیب اولین ورود چاپ کن: <code>SECTOR: T1 T2 ...</code></div>
#   <div class="box tip" dir="rtl"><b>راهنما:</b> اگر صنعت هنوز در دیکشنری نبود، یک لیست خالی برایش بساز و بعد نماد را <code>append</code> کن. پیمایش نهایی روی <code>groups.items()</code> باشد.</div>
#   <div class="box extra" dir="rtl"><b>راهنمای مفهوم کمکی:</b> این الگو را «گروه‌بندی» می‌گویند: دیکشنری از کلید به لیست. در تحلیل پرتفوی برای exposure صنعتی استفاده می‌شود.</div>
#   <div class="io">
#     <div class="pane in">
#       <div class="pane-label">ورودی نمونه</div>
#       <pre dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate;white-space:pre;">5
# FOOLAD Metals
# SHPNA Refinery
# FAKH Metals
# PNWE Refinery
# MAPNA Utility</pre>
#     </div>
#     <div class="pane out">
#       <div class="pane-label">خروجی نمونه</div>
#       <pre dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate;white-space:pre;">Metals: FOOLAD FAKH
# Refinery: SHPNA PNWE
# Utility: MAPNA</pre>
#     </div>
#   </div>
#   <div class="box why" dir="rtl"><b>چرا این خروجی؟</b> فلزات اول می‌آید چون فولاد اولین رکورد است؛ بعد پالایش با شپنا؛ بعد یوتیلیتی با مپنا. فخوز و پالایش نفت اصفهان به گروه خودشان اضافه می‌شوند.</div>
# </div>

# %%
n = int(input())
groups = {}

for i in range(n):
    ticker, sector = input().split()
    # To Do: ticker را به لیست groups[sector] اضافه کن

# To Do: هر صنعت و نمادهایش را چاپ کن

# %% [markdown]
# ###### q22
#
# <div class="qcard" dir="rtl" align="right" style="direction:rtl;text-align:right;">
#   <div class="qbar" dir="rtl" style="direction:rtl;text-align:right;">
#     <span class="qnum">سؤال ۲۲</span>
#     <span class="tags">dict · for · if</span>
#   </div>
#   <h2 style="direction:rtl;text-align:right;">وزن بیش از حد نسبت به هدف</h2>
#   <div class="qbody" dir="rtl" style="direction:rtl;text-align:right;">سیاست سرمایه‌گذاری (IPS) برای هر دارایی یک وزن هدف دارد. وزن فعلی را هم داری. اول n، بعد n خط <code>NAME TARGET ACTUAL</code> (وزن‌ها به درصد، عدد صحیح). دارایی‌هایی را چاپ کن که وزن فعلی‌شان از هدف بیشتر است؛ هر خط <code>NAME EXCESS</code>. ترتیب همان ترتیب ورودی باشد. اگر هیچ‌کدام overweight نبودند چیزی چاپ نشود.</div>
#   <div class="box tip" dir="rtl"><b>راهنما:</b> اضافه وزن یعنی <code>actual - target</code> وقتی این تفاضل مثبت است. شپنا و نقد underflow هستند و نباید چاپ شوند.</div>
#   <div class="box extra" dir="rtl"><b>راهنمای مفهوم کمکی:</b> در مدیریت پرتفوی، overweight یعنی از وزن هدف IPS فراتر رفته‌ای و باید برای ری‌بالانس کاندید فروش باشی.</div>
#   <div class="io">
#     <div class="pane in">
#       <div class="pane-label">ورودی نمونه</div>
#       <pre dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate;white-space:pre;">4
# FOOLAD 20 28
# SHPNA 25 22
# MAPNA 15 21
# Cash 40 29</pre>
#     </div>
#     <div class="pane out">
#       <div class="pane-label">خروجی نمونه</div>
#       <pre dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate;white-space:pre;">FOOLAD 8
# MAPNA 6</pre>
#     </div>
#   </div>
#   <div class="box why" dir="rtl"><b>چرا این خروجی؟</b> فولاد ۸ واحد و مپنا ۶ واحد بالای هدف‌اند. شپنا ۳ واحد و نقد ۱۱ واحد زیر هدف‌اند؛ پس در خروجی نمی‌آیند.</div>
# </div>

# %%
n = int(input())

for i in range(n):
    name, target, actual = input().split()
    target = int(target)
    actual = int(actual)
    # To Do: اگر overweight بود نام و مقدار اضافه را چاپ کن

# %% [markdown]
# ###### q23
#
# <div class="qcard" dir="rtl" align="right" style="direction:rtl;text-align:right;">
#   <div class="qbar" dir="rtl" style="direction:rtl;text-align:right;">
#     <span class="qnum">سؤال ۲۳</span>
#     <span class="tags">string · split · list</span>
#   </div>
#   <h2 style="direction:rtl;text-align:right;">تبدیل رشته بلاتر به سفارش</h2>
#   <div class="qbody" dir="rtl" style="direction:rtl;text-align:right;">میانه دفتر، بلاتر را یک رشته می‌فرستد. سفارش‌ها با <code> | </code> جدا شده‌اند و هر سفارش این شکل را دارد:<br><code>SIDE TICKER QTY @ PRICE</code><br>رشته را بگیر. برای هر سفارش یک خط چاپ کن: <code>SIDE TICKER QTY NOTIONAL</code> که ارزش اسمی برابر حجم × قیمت است.</div>
#   <div class="box tip" dir="rtl"><b>راهنما:</b> اول با <code>split(" | ")</code> سفارش‌ها را جدا کن. هر سفارش را با <code>split()</code> به واژه‌ها بشکن. علامت <code>@</code> را نادیده بگیر؛ حجم و قیمت را <code>int</code> کن.</div>
#   <div class="box extra" dir="rtl"><b>راهنمای مفهوم کمکی:</b> پارس کردن متن گزارش، کار روزانه عملیات و میانه دفتر است. اول جداکننده بزرگ، بعد فیلدهای داخل هر سفارش.</div>
#   <div class="io">
#     <div class="pane in">
#       <div class="pane-label">ورودی نمونه</div>
#       <pre dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate;white-space:pre;">BUY FOOLAD 100 @ 720 | SELL SHPNA 50 @ 1850</pre>
#     </div>
#     <div class="pane out">
#       <div class="pane-label">خروجی نمونه</div>
#       <pre dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate;white-space:pre;">BUY FOOLAD 100 72000
# SELL SHPNA 50 92500</pre>
#     </div>
#   </div>
#   <div class="box why" dir="rtl"><b>چرا این خروجی؟</b> سفارش اول ۱۰۰×۷۲۰=۷۲۰۰۰ و دومی ۵۰×۱۸۵۰=۹۲۵۰۰. دو سفارش با | جدا شده بودند.</div>
# </div>

# %%
blotter = input()

# To Do: سفارش‌ها را جدا کن و برای هر کدام side ticker qty notional را چاپ کن

# %% [markdown]
# ###### q24
#
# <div class="qcard" dir="rtl" align="right" style="direction:rtl;text-align:right;">
#   <div class="qbar" dir="rtl" style="direction:rtl;text-align:right;">
#     <span class="qnum">سؤال ۲۴</span>
#     <span class="tags">set · intersection · difference</span>
#   </div>
#   <h2 style="direction:rtl;text-align:right;">ساخت جهان سرمایه‌گذاری</h2>
#   <div class="qbody" dir="rtl" style="direction:rtl;text-align:right;">جهان سرمایه‌گذاری مجاز را این‌طور می‌سازند:<br>خط ۱: اعضای شاخص (benchmark)<br>خط ۲: نمادهای نقدشونده (liquid)<br>خط ۳: فهرست ممنوع (restricted: تحریم، اطلاعات نهانی، سقف مالکیت)<br>مجموعه مجاز برابر است با اشتراک شاخص و نقدشونده، منهای ممنوع. اول تعداد نمادهای مجاز و در خط بعد همان‌ها را الفبایی با فاصله چاپ کن.</div>
#   <div class="box tip" dir="rtl"><b>راهنما:</b> سه <code>set</code> بساز. اشتراک <code>&amp;</code> و تفاضل <code>-</code>. خروجی را <code>sorted</code> کن.</div>
#   <div class="box extra" dir="rtl"><b>راهنمای مفهوم کمکی:</b> TAPIC نقد است ولی در شاخص نیست؛ پس وارد جهان نمی‌شود. خودرو هم در اشتراک هست اما ممنوع است و حذف می‌شود.</div>
#   <div class="io">
#     <div class="pane in">
#       <div class="pane-label">ورودی نمونه</div>
#       <pre dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate;white-space:pre;">FOOLAD SHPNA MAPNA KHODRO KEGOL
# FOOLAD MAPNA KHODRO TAPIC
# KHODRO</pre>
#     </div>
#     <div class="pane out">
#       <div class="pane-label">خروجی نمونه</div>
#       <pre dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate;white-space:pre;">2
# FOOLAD MAPNA</pre>
#     </div>
#   </div>
#   <div class="box why" dir="rtl"><b>چرا این خروجی؟</b> اشتراک شاخص و نقد: فولاد، مپنا، خودرو. خودرو در فهرست ممنوع است. می‌ماند فولاد و مپنا.</div>
# </div>

# %%
benchmark = set(input().split())
liquid = set(input().split())
restricted = set(input().split())

# To Do: investable را بساز، تعداد و لیست مرتب را چاپ کن

# %% [markdown]
# ###### q25
#
# <div class="qcard" dir="rtl" align="right" style="direction:rtl;text-align:right;">
#   <div class="qbar" dir="rtl" style="direction:rtl;text-align:right;">
#     <span class="qnum">سؤال ۲۵</span>
#     <span class="tags">string · dict · slicing</span>
#   </div>
#   <h2 style="direction:rtl;text-align:right;">اعتبارسنجی شبا و کد بانک</h2>
#   <div class="qbody" dir="rtl" style="direction:rtl;text-align:right;">شماره شبا را بگیر و بانک را از روی کد شناسایی کن. دیکشنری کد بانک آماده است. قواعد اعتبارسنجی:<br>۱) فاصله‌ها را حذف کن و حروف را بزرگ کن.<br>۲) باید با <code>IR</code> شروع شود.<br>۳) طول کل باید دقیقاً ۲۶ کاراکتر باشد (IR به‌علاوه ۲۴ رقم).<br>۴) همه کاراکترهای بعد از IR باید رقم باشند: <code>iban[2:].isdigit()</code><br>۵) کد بانک سه کاراکتر از ایندکس ۴ تا ۷ است: <code>iban[4:7]</code> و باید در دیکشنری باشد.<br>اگر همه قواعد برقرار بود نام بانک را چاپ کن؛ وگرنه <code>Invalid</code>.</div>
#   <div class="box tip" dir="rtl"><b>راهنما:</b> برش <code>s[a:b]</code> از a تا قبل از b را می‌دهد. <code>replace(" ", "")</code> همه فاصله‌های وسط را هم برمی‌دارد (قوی‌تر از strip).</div>
#   <div class="box extra" dir="rtl"><b>راهنمای مفهوم کمکی:</b> در شبا بعد از IR دو رقم کنترل می‌آید، بعد سه رقم کد بانک. ۱۲ کنترل است و ۰۱۲ یعنی بانک ملت.</div>
#   <div class="io">
#     <div class="pane in">
#       <div class="pane-label">ورودی نمونه</div>
#       <pre dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate;white-space:pre;">IR12 012 0000 0000 0000 0000 024</pre>
#     </div>
#     <div class="pane out">
#       <div class="pane-label">خروجی نمونه</div>
#       <pre dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate;white-space:pre;">Mellat</pre>
#     </div>
#   </div>
#   <div class="box why" dir="rtl"><b>چرا این خروجی؟</b> بعد از حذف فاصله و upper، متن ۲۶ کاراکتری با IR شروع می‌شود، بقیه رقم‌اند و کد ۰۱۲ در دیکشنری ملت است.</div>
# </div>

# %%
banks = {
    "012": "Mellat",
    "017": "Melli",
    "019": "Saderat",
    "054": "Parsian",
    "056": "Saman",
}
raw = input()

# To Do: شبا را تمیز و اعتبارسنجی کن؛ نام بانک یا Invalid را چاپ کن

# %% [markdown]
# <div class="guide" dir="rtl" align="right" style="direction:rtl;text-align:right;">
#   <h2 style="direction:rtl;text-align:right;">پایان تمرین‌ها</h2>
#   <p>اگر هر ۲۵ سؤال را خودت کامل کرده باشی، این مهارت‌ها را در عمل دیده‌ای:</p>
#   <ul>
#     <li>ایندکس و برش لیست، <code>append</code>، <code>count</code>، <code>sum</code>، <code>join</code></li>
#     <li>خواندن و به‌روزرسانی دیکشنری، دیکشنری تو در تو، گروه‌بندی با دیکشنریِ لیست</li>
#     <li>تاپل برای سفارش و تقویم کوپن، باز کردن تاپل در حلقه</li>
#     <li>مجموعه برای صنایع یکتا، اشتراک دو صندوق، جهان سرمایه‌گذاری</li>
#     <li>متدهای رشته برای نماد، ISIN، جفت‌ارز، بلاتر و شبا</li>
#     <li>موقعیت‌های مالی مثل NAV، مومنتوم، overweight نسبت به IPS، و اعتبارسنجی شبا</li>
#   </ul>
#   <p>اگر جایی گیر کردی، اول راهنمای زرد همان سؤال را بخوان، بعد فقط همان خط <span class="kbd"># To Do</span> را عوض کن.</p>
# </div>
