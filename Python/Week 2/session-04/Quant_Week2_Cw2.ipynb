# %% [markdown]
# <div class="hero" dir="rtl" align="right" style="direction:rtl;text-align:right;">
#   <h1 style="direction:rtl;text-align:right;">بیست‌وپنج تمرین CW2</h1>
#   <p>
#     هفته ۲ · جلسه ۲ · CW2 · ایستگاه اول: پایتون مقدماتی · Zero to Quant<br>
#     هر سؤال یک موقعیت مالی دارد و زیر آن یک سلول کد ناقص است.
#     بخش‌هایی که با <b># To Do</b> مشخص شده‌اند را خودت کامل کن.
#   </p>
#   <div class="hero-meta">
#     <span class="chip">list</span>
#     <span class="chip">dictionary</span>
#     <span class="chip">tuple</span>
#     <span class="chip">set</span>
#     <span class="chip">string</span>
#     <span class="chip">۲۵ سؤال</span>
#   </div>
# </div>

# %% [markdown]
# <div class="guide" dir="rtl" align="right" style="direction:rtl;text-align:right;">
#   <h2 style="direction:rtl;text-align:right;">۰) راهنمای شروع و فونت وزیر</h2>
#   <p>متن سؤال‌ها با فونت <b>وزیرمتن (Vazirmatn)</b> و راست‌چین طراحی شده است.
#   فونت داخل پوشه <span class="kbd">fonts</span> همین پروژه است و نوت‌بوک آن را از همان‌جا فراخوانی می‌کند.</p>
#   <div class="step"><b>مرحله ۱ — اجباری:</b> سلول کد پایین را همین حالا اجرا کن تا فونت و رنگ‌ها اعمال شود.</div>
#   <div class="step"><b>مرحله ۲ — پیشنهادی:</b> اگر می‌خواهی فونت روی کل ویندوز نصب شود، برو به پوشه <span class="kbd">fonts</span> و روی فایل‌های <span class="kbd">.ttf</span> راست‌کلیک کن و <b>Install</b> بزن.
#   راهنمای کامل‌تر داخل <span class="kbd">fonts/راهنمای_نصب_فونت.md</span> است.</div>
#   <div class="step"><b>مرحله ۳:</b> هر سؤال را بخوان، سلول کد زیرش را کامل کن، بعد اجرا کن و با خروجی نمونه مقایسه کن.</div>
#   <p>اگر فونت دیده نشد: مطمئن شو نوت‌بوک را از پوشه‌ای باز کرده‌ای که پوشه <span class="kbd">fonts</span> کنار آن است، بعد همین سلول اول را دوباره Run کن.</p>
# </div>

# %%
# این سلول را اول از همه اجرا کن تا فونت وزیر و استایل سؤال‌ها فعال شود.
from IPython.display import HTML, display
from pathlib import Path

font_dir = Path("fonts")
needed = [
    "Vazirmatn-Regular.woff2",
    "Vazirmatn-Medium.woff2",
    "Vazirmatn-Bold.woff2",
    "notebook_style.html",
]
missing = [name for name in needed if not (font_dir / name).exists()]
if missing:
    print("هشدار: این فایل‌ها پیدا نشد:", ", ".join(missing))
    print("نوت‌بوک را از پوشه پروژه باز کن.")
else:
    print("فونت وزیر از پوشه fonts آماده است.")

style = Path("fonts/notebook_style.html").read_text(encoding="utf-8")
display(HTML(style))
print("استایل و فونت وزیر اعمال شد. حالا سؤال‌ها باید فارسی و رنگی دیده شوند.")

# %% [markdown]
# <div class="help" dir="rtl" align="right" style="direction:rtl;text-align:right;">
#   <h2 style="direction:rtl;text-align:right;">مفاهیم کمکی که ممکن است در بعضی سؤال‌ها ببینی</h2>
#   <p>درس این جلسه همین‌هاست: <code>list</code> · <code>dict</code> · <code>tuple</code> · <code>set</code> · متدهای <code>string</code></p>
#   <ul>
#     <li>لیست: <code>items[0]</code> اول، <code>items[-1]</code> آخر، <code>items[-3:]</code> سه عضو آخر، <code>append</code> اضافه به ته.</li>
#     <li>دیکشنری: <code>d[key]</code> مقدار کلید، <code>d[key] = v</code> نوشتن، <code>d.items()</code> پیمایش جفت‌ها.</li>
#     <li>تاپل: مثل لیست است ولی عوض نمی‌شود. باز کردن: <code>a, b = pair</code>.</li>
#     <li>مجموعه: عضو تکراری ندارد. اشتراک <code>&amp;</code> · اجتماع <code>|</code> · تفاضل <code>-</code>.</li>
#     <li>رشته: <code>upper</code> · <code>strip</code> · <code>split</code> · <code>join</code> · <code>replace</code> · <code>startswith</code> · <code>isdigit</code>.</li>
#     <li><code>sorted(x)</code> یک لیست مرتب‌شده برمی‌گرداند؛ برای چاپ مجموعه از آن استفاده کن تا ترتیب ثابت باشد.</li>
#     <li>از هفته قبل: <code>input</code> · <code>int</code> · <code>if / elif / else</code> · <code>for</code> هنوز این‌جا لازم‌اند.</li>
#   </ul>
# </div>

# %% [markdown]
# <div class="toc" dir="rtl" align="right" style="direction:rtl;text-align:right;">
#   <h2 style="direction:rtl;text-align:right;">فهرست سؤال‌ها</h2>
# </div>
#
# 1. [سؤال ۱ — ابتدا و انتهای موج سکه](#q1)
# 2. [سؤال ۲ — حباب روی تابلوی سکه](#q2)
# 3. [سؤال ۳ — مظنه اونس جهانی](#q3)
# 4. [سؤال ۴ — محرک‌های یکتای تورم](#q4)
# 5. [سؤال ۵ — کد استاندارد ارز](#q5)
# 6. [سؤال ۶ — پاک‌سازی چاپ تورم](#q6)
# 7. [سؤال ۷ — روزهای تشدید حباب](#q7)
# 8. [سؤال ۸ — سطر تابلوی سکه](#q8)
# 9. [سؤال ۹ — دلار آزاد یا رسمی](#q9)
# 10. [سؤال ۱۰ — پیامک سبد سکه](#q10)
# 11. [سؤال ۱۱ — ثبت نرخ تازه دلار](#q11)
# 12. [سؤال ۱۲ — تغییر حباب در سه روز](#q12)
# 13. [سؤال ۱۳ — به‌روزرسانی نرخ سود](#q13)
# 14. [سؤال ۱۴ — ماه مشترک جهش قیمت](#q14)
# 15. [سؤال ۱۵ — ارزش یک صد دلار](#q15)
# 16. [سؤال ۱۶ — دستور جلسه سیاست پولی](#q16)
# 17. [سؤال ۱۷ — فقط سکه‌های داغ](#q17)
# 18. [سؤال ۱۸ — کد کثیف بازار ارز](#q18)
# 19. [سؤال ۱۹ — شکاف دلار آزاد](#q19)
# 20. [سؤال ۲۰ — نرخ بهره حقیقی سال](#q20)
# 21. [سؤال ۲۱ — گروه‌بندی بازارهای حباب](#q21)
# 22. [سؤال ۲۲ — عبور حباب از سقف تحلیلی](#q22)
# 23. [سؤال ۲۳ — حراج سکه بانک مرکزی](#q23)
# 24. [سؤال ۲۴ — جهان مجاز صندوق طلا](#q24)
# 25. [سؤال ۲۵ — اعتبارسنجی کد تورم](#q25)

# %% [markdown]
# ###### q1
#
# <div class="qcard" dir="rtl" align="right" style="direction:rtl;text-align:right;">
#   <div class="qbar" dir="rtl" style="direction:rtl;text-align:right;">
#     <span class="qnum">سؤال ۱</span>
#     <span class="tags">list · indexing</span>
#   </div>
#   <h2 style="direction:rtl;text-align:right;">ابتدا و انتهای موج سکه</h2>
#   <div class="qbody" dir="rtl" style="direction:rtl;text-align:right;">میز طلا سری قیمت بازار سکه امامی را دارد؛ واحد تومان است و ایندکس صفر قدیمی‌ترین مشاهده است. برای دیدن موج قیمت، اولین قیمت و آخرین قیمت را هر کدام در یک خط چاپ کن.</div>
#   <div class="box tip" dir="rtl"><b>راهنما:</b> ایندکس <code>0</code> اولین عضو است. ایندکس <code>-1</code> آخرین عضو را می‌دهد.</div>
#   <div class="box extra" dir="rtl"><b>راهنمای مفهوم کمکی:</b> حباب سکه روی همین قیمت بازار می‌نشیند: ارزش ذاتی تقریباً وزن طلا ضرب در اونس جهانی ضرب در دلار است. فاصله این دو، حباب است.</div>
#   <div class="io">
#     <div class="pane in">
#       <div class="pane-label">ورودی نمونه</div>
#       <pre dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate;white-space:pre;">این سؤال ورودی ندارد</pre>
#     </div>
#     <div class="pane out">
#       <div class="pane-label">خروجی نمونه</div>
#       <pre dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate;white-space:pre;">68500000
# 74800000</pre>
#     </div>
#   </div>
#   <div class="box why" dir="rtl"><b>چرا این خروجی؟</b> چهار مشاهده در لیست است. شروع موج ۶۸۵۰۰۰۰۰ تومان و آخرین چاپ ۷۴۸۰۰۰۰۰ تومان است.</div>
# </div>

# %%
prices = [68500000, 70200000, 73100000, 74800000]

# To Do: اولین قیمت را چاپ کن
# To Do: آخرین قیمت را چاپ کن

# %% [markdown]
# ###### q2
#
# <div class="qcard" dir="rtl" align="right" style="direction:rtl;text-align:right;">
#   <div class="qbar" dir="rtl" style="direction:rtl;text-align:right;">
#     <span class="qnum">سؤال ۲</span>
#     <span class="tags">dict · indexing</span>
#   </div>
#   <h2 style="direction:rtl;text-align:right;">حباب روی تابلوی سکه</h2>
#   <div class="qbody" dir="rtl" style="direction:rtl;text-align:right;">درصد حباب هر قطعه از قبل حساب شده و در یک دیکشنری است: کلید نوع سکه، مقدار درصد حباب. امامی همان سکه تمام، Half نیم‌سکه، Quarter ربع‌سکه و Gram سکه گرمی است. نام قطعه را از ورودی بگیر و درصد حبابش را چاپ کن.</div>
#   <div class="box tip" dir="rtl"><b>راهنما:</b> مقدار کلید <code>k</code> را با <code>bubbles[k]</code> می‌گیری.</div>
#   <div class="box extra" dir="rtl"><b>راهنمای مفهوم کمکی:</b> سکه کوچک‌تر معمولاً درصد حباب بالاتری دارد، چون حق ضرب و تقاضای نقدشوندگی روی وزن کمتری سرشکن می‌شود.</div>
#   <div class="io">
#     <div class="pane in">
#       <div class="pane-label">ورودی نمونه</div>
#       <pre dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate;white-space:pre;">Quarter</pre>
#     </div>
#     <div class="pane out">
#       <div class="pane-label">خروجی نمونه</div>
#       <pre dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate;white-space:pre;">41</pre>
#     </div>
#   </div>
#   <div class="box why" dir="rtl"><b>چرا این خروجی؟</b> کلید Quarter در تابلو مقدار ۴۱ دارد؛ یعنی ربع‌سکه در این نمونه ۴۱ درصد بالای ارزش ذاتی معامله می‌شود.</div>
# </div>

# %%
bubbles = {"Emami": 18, "Half": 27, "Quarter": 41, "Gram": 55}
coin = input()

# To Do: درصد حباب coin را چاپ کن

# %% [markdown]
# ###### q3
#
# <div class="qcard" dir="rtl" align="right" style="direction:rtl;text-align:right;">
#   <div class="qbar" dir="rtl" style="direction:rtl;text-align:right;">
#     <span class="qnum">سؤال ۳</span>
#     <span class="tags">tuple · unpack</span>
#   </div>
#   <h2 style="direction:rtl;text-align:right;">مظنه اونس جهانی</h2>
#   <div class="qbody" dir="rtl" style="direction:rtl;text-align:right;">مظنه اونس جهانی یک تاپل ثابت است: نماد، قیمت خرید بازار (bid)، قیمت فروش بازار (ask). تاپل را باز کن و یک خط به شکل <code>SYMBOL BID bid ASK ask</code> چاپ کن.</div>
#   <div class="box tip" dir="rtl"><b>راهنما:</b> می‌توانی بنویسی <code>symbol, bid, ask = quote</code>.</div>
#   <div class="box extra" dir="rtl"><b>راهنمای مفهوم کمکی:</b> bid قیمتی است که بازار طلا را می‌خرد و ask قیمتی است که می‌فروشد. اختلافشان اسپرد است. تاپل را برای مظنه‌ای که نباید وسط محاسبه عوض شود نگه می‌داریم.</div>
#   <div class="io">
#     <div class="pane in">
#       <div class="pane-label">ورودی نمونه</div>
#       <pre dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate;white-space:pre;">این سؤال ورودی ندارد</pre>
#     </div>
#     <div class="pane out">
#       <div class="pane-label">خروجی نمونه</div>
#       <pre dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate;white-space:pre;">XAU BID 2650 ASK 2654</pre>
#     </div>
#   </div>
#   <div class="box why" dir="rtl"><b>چرا این خروجی؟</b> سه مقدار تاپل XAU و ۲۶۵۰ و ۲۶۵۴ هستند و دقیقاً با همین ترتیب در خط گزارش می‌آیند.</div>
# </div>

# %%
quote = ("XAU", 2650, 2654)

# To Do: تاپل را باز کن و خط مظنه را چاپ کن

# %% [markdown]
# ###### q4
#
# <div class="qcard" dir="rtl" align="right" style="direction:rtl;text-align:right;">
#   <div class="qbar" dir="rtl" style="direction:rtl;text-align:right;">
#     <span class="qnum">سؤال ۴</span>
#     <span class="tags">set · len</span>
#   </div>
#   <h2 style="direction:rtl;text-align:right;">محرک‌های یکتای تورم</h2>
#   <div class="qbody" dir="rtl" style="direction:rtl;text-align:right;">یادداشت تحلیلگر، محرک‌های تورم این ماه را فهرست کرده و بعضی نام‌ها تکرار شده‌اند. برای گزارش، تعداد محرک‌های <b>یکتا</b> را چاپ کن.</div>
#   <div class="box tip" dir="rtl"><b>راهنما:</b> از لیست یک <code>set</code> بساز تا تکرار حذف شود، بعد <code>len</code> بگیر.</div>
#   <div class="box extra" dir="rtl"><b>راهنمای مفهوم کمکی:</b> <code>set(list)</code> فقط مقدارهای متمایز را نگه می‌دارد. غذا، مسکن، ارز و انرژی چهار محرک جدا هستند.</div>
#   <div class="io">
#     <div class="pane in">
#       <div class="pane-label">ورودی نمونه</div>
#       <pre dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate;white-space:pre;">این سؤال ورودی ندارد</pre>
#     </div>
#     <div class="pane out">
#       <div class="pane-label">خروجی نمونه</div>
#       <pre dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate;white-space:pre;">4</pre>
#     </div>
#   </div>
#   <div class="box why" dir="rtl"><b>چرا این خروجی؟</b> Food سه بار و Housing دو بار آمده. FX و Energy هر کدام یک بارند. چهار محرک متمایز می‌ماند.</div>
# </div>

# %%
drivers = ["Food", "Housing", "Food", "FX", "Energy", "Housing", "Food"]

# To Do: تعداد محرک‌های یکتا را چاپ کن

# %% [markdown]
# ###### q5
#
# <div class="qcard" dir="rtl" align="right" style="direction:rtl;text-align:right;">
#   <div class="qbar" dir="rtl" style="direction:rtl;text-align:right;">
#     <span class="qnum">سؤال ۵</span>
#     <span class="tags">string · upper</span>
#   </div>
#   <h2 style="direction:rtl;text-align:right;">کد استاندارد ارز</h2>
#   <div class="qbody" dir="rtl" style="direction:rtl;text-align:right;">کد ارز را از ورودی بگیر و برای ثبت در سامانه تسویه با حروف بزرگ بنویس. سامانه <code>usd</code> و <code>USD</code> را یکی نمی‌داند.</div>
#   <div class="box tip" dir="rtl"><b>راهنما:</b> متد <code>s.upper()</code> حرف‌های متن را بزرگ می‌کند.</div>
#
#   <div class="io">
#     <div class="pane in">
#       <div class="pane-label">ورودی نمونه</div>
#       <pre dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate;white-space:pre;">usd</pre>
#     </div>
#     <div class="pane out">
#       <div class="pane-label">خروجی نمونه</div>
#       <pre dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate;white-space:pre;">USD</pre>
#     </div>
#   </div>
#   <div class="box why" dir="rtl"><b>چرا این خروجی؟</b> ورودی usd است؛ بعد از upper دقیقاً USD می‌شود.</div>
# </div>

# %%
code = input()

# To Do: نسخه حروف‌بزرگ code را چاپ کن

# %% [markdown]
# ###### q6
#
# <div class="qcard" dir="rtl" align="right" style="direction:rtl;text-align:right;">
#   <div class="qbar" dir="rtl" style="direction:rtl;text-align:right;">
#     <span class="qnum">سؤال ۶</span>
#     <span class="tags">string · strip</span>
#   </div>
#   <h2 style="direction:rtl;text-align:right;">پاک‌سازی چاپ تورم</h2>
#   <div class="qbody" dir="rtl" style="direction:rtl;text-align:right;">عدد تورم از جدول یک گزارش کپی شده و دو طرفش فاصله دارد. فاصله‌های اول و آخر را حذف کن و همان متن را چاپ کن. آن را به عدد تبدیل نکن.</div>
#   <div class="box tip" dir="rtl"><b>راهنما:</b> <code>s.strip()</code> فقط فاصله و خط جدید دو سر رشته را برمی‌دارد.</div>
#
#   <div class="io">
#     <div class="pane in">
#       <div class="pane-label">ورودی نمونه</div>
#       <pre dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate;white-space:pre;">این سؤال ورودی ندارد</pre>
#     </div>
#     <div class="pane out">
#       <div class="pane-label">خروجی نمونه</div>
#       <pre dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate;white-space:pre;">35.20</pre>
#     </div>
#   </div>
#   <div class="box why" dir="rtl"><b>چرا این خروجی؟</b> متن با فاصله شروع و تمام می‌شود. strip خود 35.20 را با صفر آخر نگه می‌دارد. اگر float کنی، صفر آخر می‌افتد و چاپ 35.2 می‌شود که جواب این سؤال نیست.</div>
# </div>

# %%
cpi = "  35.20  "

# To Do: فاصله‌های دو سر را حذف کن و چاپ کن

# %% [markdown]
# ###### q7
#
# <div class="qcard" dir="rtl" align="right" style="direction:rtl;text-align:right;">
#   <div class="qbar" dir="rtl" style="direction:rtl;text-align:right;">
#     <span class="qnum">سؤال ۷</span>
#     <span class="tags">list · count</span>
#   </div>
#   <h2 style="direction:rtl;text-align:right;">روزهای تشدید حباب</h2>
#   <div class="qbody" dir="rtl" style="direction:rtl;text-align:right;">هر روز حباب سکه یکی از این برچسب‌ها را گرفته: <code>UP</code> یعنی حباب بازتر شده، <code>DOWN</code> یعنی جمع شده، <code>FLAT</code> یعنی تغییر نکرده. تعداد روزهای <code>UP</code> را چاپ کن.</div>
#   <div class="box tip" dir="rtl"><b>راهنما:</b> <code>items.count(x)</code> می‌گوید x چند بار در لیست آمده است.</div>
#
#   <div class="io">
#     <div class="pane in">
#       <div class="pane-label">ورودی نمونه</div>
#       <pre dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate;white-space:pre;">این سؤال ورودی ندارد</pre>
#     </div>
#     <div class="pane out">
#       <div class="pane-label">خروجی نمونه</div>
#       <pre dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate;white-space:pre;">4</pre>
#     </div>
#   </div>
#   <div class="box why" dir="rtl"><b>چرا این خروجی؟</b> شش روز هست: چهار UP، یک DOWN و یک FLAT. فقط UP شمرده می‌شود، پس جواب ۴ است.</div>
# </div>

# %%
moves = ["UP", "DOWN", "UP", "UP", "FLAT", "UP"]

# To Do: تعداد UP را چاپ کن

# %% [markdown]
# ###### q8
#
# <div class="qcard" dir="rtl" align="right" style="direction:rtl;text-align:right;">
#   <div class="qbar" dir="rtl" style="direction:rtl;text-align:right;">
#     <span class="qnum">سؤال ۸</span>
#     <span class="tags">string · split</span>
#   </div>
#   <h2 style="direction:rtl;text-align:right;">سطر تابلوی سکه</h2>
#   <div class="qbody" dir="rtl" style="direction:rtl;text-align:right;">یک سطر تابلوی سکه سه بخش دارد که با فاصله جدا شده‌اند: نام قطعه، قیمت بازار به تومان، درصد حباب. سطر را بگیر، به سه بخش بشکن و هر بخش را در یک خط چاپ کن.</div>
#   <div class="box tip" dir="rtl"><b>راهنما:</b> <code>s.split()</code> متن را از روی فاصله به لیست واژه‌ها تبدیل می‌کند. بعد هر واژه را چاپ کن.</div>
#
#   <div class="io">
#     <div class="pane in">
#       <div class="pane-label">ورودی نمونه</div>
#       <pre dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate;white-space:pre;">Emami 74800000 18</pre>
#     </div>
#     <div class="pane out">
#       <div class="pane-label">خروجی نمونه</div>
#       <pre dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate;white-space:pre;">Emami
# 74800000
# 18</pre>
#     </div>
#   </div>
#   <div class="box why" dir="rtl"><b>چرا این خروجی؟</b> سه واژه Emami و 74800000 و 18 است. قیمت و درصد هنوز متن‌اند و در این سؤال نباید عدد شوند.</div>
# </div>

# %%
board = input()

# To Do: board را split کن و هر بخش را در یک خط چاپ کن

# %% [markdown]
# ###### q9
#
# <div class="qcard" dir="rtl" align="right" style="direction:rtl;text-align:right;">
#   <div class="qbar" dir="rtl" style="direction:rtl;text-align:right;">
#     <span class="qnum">سؤال ۹</span>
#     <span class="tags">string · startswith</span>
#   </div>
#   <h2 style="direction:rtl;text-align:right;">دلار آزاد یا رسمی</h2>
#   <div class="qbody" dir="rtl" style="direction:rtl;text-align:right;">کد سری ارز از قبل تمیز و با حروف بزرگ است. اگر با <code>F</code> شروع شود بازار آزاد است و <code>Free</code> چاپ کن؛ وگرنه <code>Official</code>.</div>
#   <div class="box tip" dir="rtl"><b>راهنما:</b> <code>s.startswith("F")</code> بررسی می‌کند متن با F شروع می‌شود یا نه.</div>
#   <div class="box extra" dir="rtl"><b>راهنمای مفهوم کمکی:</b> FUSD دلار آزاد است. سری رسمی، مثل دلار نیمایی، با حرف دیگری شروع می‌شود و Official حساب می‌شود.</div>
#   <div class="io">
#     <div class="pane in">
#       <div class="pane-label">ورودی نمونه</div>
#       <pre dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate;white-space:pre;">FUSD</pre>
#     </div>
#     <div class="pane out">
#       <div class="pane-label">خروجی نمونه</div>
#       <pre dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate;white-space:pre;">Free</pre>
#     </div>
#   </div>
#   <div class="box why" dir="rtl"><b>چرا این خروجی؟</b> نمونه با F شروع می‌شود؛ پس بازار آزاد است و Free چاپ می‌شود.</div>
# </div>

# %%
series = input()

# To Do: با if تصمیم بگیر Free یا Official

# %% [markdown]
# ###### q10
#
# <div class="qcard" dir="rtl" align="right" style="direction:rtl;text-align:right;">
#   <div class="qbar" dir="rtl" style="direction:rtl;text-align:right;">
#     <span class="qnum">سؤال ۱۰</span>
#     <span class="tags">list · join</span>
#   </div>
#   <h2 style="direction:rtl;text-align:right;">پیامک سبد سکه</h2>
#   <div class="qbody" dir="rtl" style="direction:rtl;text-align:right;">سبد سکه صندوق را به یک رشته تبدیل کن تا در پیامک کمیته سرمایه‌گذاری برود. نام‌ها باید با <code> | </code> به هم بچسبند (فاصله، خط عمودی، فاصله).</div>
#   <div class="box tip" dir="rtl"><b>راهنما:</b> <code>" | ".join(coins)</code> اعضای لیست را با همان جداکننده به یک متن تبدیل می‌کند.</div>
#   <div class="box extra" dir="rtl"><b>راهنمای مفهوم کمکی:</b> برعکس <code>split</code> است: split متن را به لیست می‌کند، join لیست را به متن.</div>
#   <div class="io">
#     <div class="pane in">
#       <div class="pane-label">ورودی نمونه</div>
#       <pre dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate;white-space:pre;">این سؤال ورودی ندارد</pre>
#     </div>
#     <div class="pane out">
#       <div class="pane-label">خروجی نمونه</div>
#       <pre dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate;white-space:pre;">Emami | Half | Quarter</pre>
#     </div>
#   </div>
#   <div class="box why" dir="rtl"><b>چرا این خروجی؟</b> سه قطعه با جداکننده مشخص به یک خط تبدیل می‌شوند. قبل از اولی و بعد از آخری خط عمودی نمی‌آید.</div>
# </div>

# %%
coins = ["Emami", "Half", "Quarter"]

# To Do: نام‌ها را با جداکننده « | » بچسبان و چاپ کن

# %% [markdown]
# ###### q11
#
# <div class="qcard" dir="rtl" align="right" style="direction:rtl;text-align:right;">
#   <div class="qbar" dir="rtl" style="direction:rtl;text-align:right;">
#     <span class="qnum">سؤال ۱۱</span>
#     <span class="tags">list · append</span>
#   </div>
#   <h2 style="direction:rtl;text-align:right;">ثبت نرخ تازه دلار</h2>
#   <div class="qbody" dir="rtl" style="direction:rtl;text-align:right;">سری دلار آزاد دو نرخ قبلی را دارد (تومان برای هر دلار). نرخ امروز را از ورودی بگیر، به انتهای لیست اضافه کن، بعد کل سری را با فاصله در یک خط چاپ کن.</div>
#   <div class="box tip" dir="rtl"><b>راهنما:</b> <code>usd.append(x)</code> عضو را به ته لیست اضافه می‌کند. ورودی خودش متن است؛ لازم نیست int کنی. برای چاپ یک‌خطی از <code>join</code> با فاصله استفاده کن.</div>
#
#   <div class="io">
#     <div class="pane in">
#       <div class="pane-label">ورودی نمونه</div>
#       <pre dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate;white-space:pre;">87100</pre>
#     </div>
#     <div class="pane out">
#       <div class="pane-label">خروجی نمونه</div>
#       <pre dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate;white-space:pre;">84200 85600 87100</pre>
#     </div>
#   </div>
#   <div class="box why" dir="rtl"><b>چرا این خروجی؟</b> اول ۸۴۲۰۰ و ۸۵۶۰۰ بودند. ۸۷۱۰۰ به ته لیست اضافه شد و سه نرخ با فاصله چاپ می‌شوند.</div>
# </div>

# %%
usd = ["84200", "85600"]
latest = input()

# To Do: latest را به سری اضافه کن
# To Do: همه نرخ‌ها را با فاصله در یک خط چاپ کن

# %% [markdown]
# ###### q12
#
# <div class="qcard" dir="rtl" align="right" style="direction:rtl;text-align:right;">
#   <div class="qbar" dir="rtl" style="direction:rtl;text-align:right;">
#     <span class="qnum">سؤال ۱۲</span>
#     <span class="tags">list · slicing</span>
#   </div>
#   <h2 style="direction:rtl;text-align:right;">تغییر حباب در سه روز</h2>
#   <div class="qbody" dir="rtl" style="direction:rtl;text-align:right;">درصد حباب سکه امامی در یک لیست آمده است؛ ایندکس صفر یعنی قدیمی‌ترین روز. فقط <b>سه روز آخر</b> را پنجره کوتاه‌مدت بگیر و تغییر حباب از ابتدای این پنجره تا انتهایش را چاپ کن (آخر پنجره منهای اول پنجره).</div>
#   <div class="box tip" dir="rtl"><b>راهنما:</b> برش <code>bubble[-3:]</code> سه عضو آخر را می‌دهد. تغییر برابر است با <code>window[-1] - window[0]</code>.</div>
#   <div class="box extra" dir="rtl"><b>راهنمای مفهوم کمکی:</b> در پایتون <code>a[start:end]</code> از start تا قبل از end را برمی‌دارد. ایندکس منفی از ته لیست می‌شمارد. این تغییر بر حسب واحد درصد است و اگر حباب جمع شده باشد منفی می‌شود.</div>
#   <div class="io">
#     <div class="pane in">
#       <div class="pane-label">ورودی نمونه</div>
#       <pre dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate;white-space:pre;">این سؤال ورودی ندارد</pre>
#     </div>
#     <div class="pane out">
#       <div class="pane-label">خروجی نمونه</div>
#       <pre dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate;white-space:pre;">1</pre>
#     </div>
#   </div>
#   <div class="box why" dir="rtl"><b>چرا این خروجی؟</b> سه روز آخر ۱۸ و ۲۲ و ۱۹ هستند. سؤال قله ۲۲ را نمی‌خواهد؛ تغییر ابتدا تا انتها است: ۱۹−۱۸=۱.</div>
# </div>

# %%
bubble = [12, 15, 14, 18, 22, 19]

# To Do: تغییر حباب در پنجره سه روز آخر را چاپ کن

# %% [markdown]
# ###### q13
#
# <div class="qcard" dir="rtl" align="right" style="direction:rtl;text-align:right;">
#   <div class="qbar" dir="rtl" style="direction:rtl;text-align:right;">
#     <span class="qnum">سؤال ۱۳</span>
#     <span class="tags">dict · update</span>
#   </div>
#   <h2 style="direction:rtl;text-align:right;">به‌روزرسانی نرخ سود</h2>
#   <div class="qbody" dir="rtl" style="direction:rtl;text-align:right;">سه نرخ مهم در یک دیکشنری است: سود سپرده، نرخ بین‌بانکی و نرخ سیاستی. نام نرخ و مقدار جدید را بگیر، همان کلید را به‌روز کن، بعد برای هر نرخ یک خط <code>name value</code> چاپ کن (ترتیب همان ترتیب دیکشنری).</div>
#   <div class="box tip" dir="rtl"><b>راهنما:</b> نوشتن <code>rates[name] = new_val</code> اگر کلید از قبل باشد مقدار را عوض می‌کند. مقدار جدید را با <code>int</code> عدد کن. برای پیمایش از <code>rates.items()</code> استفاده کن.</div>
#   <div class="box extra" dir="rtl"><b>راهنمای مفهوم کمکی:</b> این سه نرخ یکی نیستند. سپرده هزینه تجهیز پول بانک است، بین‌بانکی قیمت مبادله ذخایر بین بانک‌هاست و نرخ سیاستی ابزار بانک مرکزی است.</div>
#   <div class="io">
#     <div class="pane in">
#       <div class="pane-label">ورودی نمونه</div>
#       <pre dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate;white-space:pre;">Interbank
# 24</pre>
#     </div>
#     <div class="pane out">
#       <div class="pane-label">خروجی نمونه</div>
#       <pre dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate;white-space:pre;">Deposit 20
# Interbank 24
# Policy 21</pre>
#     </div>
#   </div>
#   <div class="box why" dir="rtl"><b>چرا این خروجی؟</b> فقط نرخ بین‌بانکی از ۲۳ به ۲۴ می‌رسد. سپرده ۲۰ و نرخ سیاستی ۲۱ دست‌نخورده می‌مانند.</div>
# </div>

# %%
rates = {"Deposit": 20, "Interbank": 23, "Policy": 21}
name = input()
new_val = int(input())

# To Do: نرخ name را عوض کن
# To Do: همه نرخ‌ها را چاپ کن

# %% [markdown]
# ###### q14
#
# <div class="qcard" dir="rtl" align="right" style="direction:rtl;text-align:right;">
#   <div class="qbar" dir="rtl" style="direction:rtl;text-align:right;">
#     <span class="qnum">سؤال ۱۴</span>
#     <span class="tags">set · intersection</span>
#   </div>
#   <h2 style="direction:rtl;text-align:right;">ماه مشترک جهش قیمت</h2>
#   <div class="qbody" dir="rtl" style="direction:rtl;text-align:right;">دو خط می‌گیری. خط اول ماه‌هایی است که تورم مصرف‌کننده جهش کرده و خط دوم ماه‌های جهش تورم تولیدکننده. کد ماه‌ها انگلیسی است. ماه‌های مشترک را به‌صورت الفبایی و با فاصله در یک خط چاپ کن، نه به ترتیب تقویم.</div>
#   <div class="box tip" dir="rtl"><b>راهنما:</b> هر خط را <code>split</code> کن و <code>set</code> بساز. اشتراک دو مجموعه با <code>a &amp; b</code> به‌دست می‌آید. قبل از چاپ <code>sorted</code> کن تا ترتیب ثابت و الفبایی باشد.</div>
#   <div class="box extra" dir="rtl"><b>راهنمای مفهوم کمکی:</b> <code>sorted(s)</code> از مجموعه یک لیست مرتب می‌سازد. اجتماع <code>|</code> و تفاضل <code>-</code> است.</div>
#   <div class="io">
#     <div class="pane in">
#       <div class="pane-label">ورودی نمونه</div>
#       <pre dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate;white-space:pre;">Jan Mar Jun Sep
# Jun Sep Dec</pre>
#     </div>
#     <div class="pane out">
#       <div class="pane-label">خروجی نمونه</div>
#       <pre dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate;white-space:pre;">Jun Sep</pre>
#     </div>
#   </div>
#   <div class="box why" dir="rtl"><b>چرا این خروجی؟</b> ژوئن و سپتامبر در هر دو خط هستند. مارس فقط در تورم مصرف‌کننده است و دسامبر فقط در تورم تولیدکننده. خروجی الفبایی می‌شود Jun سپس Sep.</div>
# </div>

# %%
line1 = input()
line2 = input()

# To Do: دو مجموعه بساز، اشتراک را بگیر، مرتب چاپ کن

# %% [markdown]
# ###### q15
#
# <div class="qcard" dir="rtl" align="right" style="direction:rtl;text-align:right;">
#   <div class="qbar" dir="rtl" style="direction:rtl;text-align:right;">
#     <span class="qnum">سؤال ۱۵</span>
#     <span class="tags">string · split</span>
#   </div>
#   <h2 style="direction:rtl;text-align:right;">ارزش یک صد دلار</h2>
#   <div class="qbody" dir="rtl" style="direction:rtl;text-align:right;">یک خط از تابلوی ارز به شکل <code>CODE:RATE</code> می‌آید؛ نرخ یعنی تومان برای هر دلار. کد ارز، نرخ، و ارزش ۱۰۰ دلار (نرخ × ۱۰۰) را هر کدام در یک خط چاپ کن.</div>
#   <div class="box tip" dir="rtl"><b>راهنما:</b> با <code>split(":")</code> دو بخش بساز. بخش دوم هنوز متن است؛ با <code>int</code> عددش کن.</div>
#
#   <div class="io">
#     <div class="pane in">
#       <div class="pane-label">ورودی نمونه</div>
#       <pre dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate;white-space:pre;">USD:87100</pre>
#     </div>
#     <div class="pane out">
#       <div class="pane-label">خروجی نمونه</div>
#       <pre dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate;white-space:pre;">USD
# 87100
# 8710000</pre>
#     </div>
#   </div>
#   <div class="box why" dir="rtl"><b>چرا این خروجی؟</b> کد USD و نرخ ۸۷۱۰۰ است. صد دلار ۸۷۱۰۰۰۰ تومان می‌ارزد.</div>
# </div>

# %%
text = input()

# To Do: کد و نرخ را جدا کن، بعد ارزش ۱۰۰ دلار را هم چاپ کن

# %% [markdown]
# ###### q16
#
# <div class="qcard" dir="rtl" align="right" style="direction:rtl;text-align:right;">
#   <div class="qbar" dir="rtl" style="direction:rtl;text-align:right;">
#     <span class="qnum">سؤال ۱۶</span>
#     <span class="tags">tuple · list · for</span>
#   </div>
#   <h2 style="direction:rtl;text-align:right;">دستور جلسه سیاست پولی</h2>
#   <div class="qbody" dir="rtl" style="direction:rtl;text-align:right;">تقویم شورای سیاست پولی یک تاپل ثابت از شماره ماه‌هاست و وسط سال عوض نمی‌شود. دستور جلسه امسال لیستی از تاپل‌های <code>(month, event)</code> است. فقط رویدادهایی را چاپ کن که ماه‌شان واقعاً جلسه سیاستی دارد؛ هر کدام یک خط، فقط نام رویداد.</div>
#   <div class="box tip" dir="rtl"><b>راهنما:</b> روی لیست حلقه بزن، تاپل را باز کن، و فقط وقتی <code>month in meetings</code> بود نام رویداد را چاپ کن.</div>
#   <div class="box extra" dir="rtl"><b>راهنمای مفهوم کمکی:</b> هر موضوع روی دستور جلسه، تصمیم نرخ بهره نیست. بودجه و ارز و اختتامیه در ماه‌هایی هستند که جلسه سیاستی ندارند.</div>
#   <div class="io">
#     <div class="pane in">
#       <div class="pane-label">ورودی نمونه</div>
#       <pre dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate;white-space:pre;">این سؤال ورودی ندارد</pre>
#     </div>
#     <div class="pane out">
#       <div class="pane-label">خروجی نمونه</div>
#       <pre dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate;white-space:pre;">Rate
# Inflation</pre>
#     </div>
#   </div>
#   <div class="box why" dir="rtl"><b>چرا این خروجی؟</b> جلسات در ماه‌های ۱ و ۴ و ۷ و ۱۰ است. از دستور جلسه فقط Rate در ماه ۴ و Inflation در ماه ۷ روی این تقویم می‌افتند.</div>
# </div>

# %%
meetings = (1, 4, 7, 10)
agenda = [(3, "Budget"), (4, "Rate"), (6, "FX"), (7, "Inflation"), (12, "Close")]

# To Do: فقط رویدادهای ماه جلسه را چاپ کن
for month, event in agenda:
    # To Do: شرط عضویت ماه در تقویم

# %% [markdown]
# ###### q17
#
# <div class="qcard" dir="rtl" align="right" style="direction:rtl;text-align:right;">
#   <div class="qbar" dir="rtl" style="direction:rtl;text-align:right;">
#     <span class="qnum">سؤال ۱۷</span>
#     <span class="tags">list · tuple · for</span>
#   </div>
#   <h2 style="direction:rtl;text-align:right;">فقط سکه‌های داغ</h2>
#   <div class="qbody" dir="rtl" style="direction:rtl;text-align:right;">میز ریسک برای تغییر روزانه حباب هر سکه یک برچسب زده است. هر ردیف یک تاپل <code>(coin, change, tag)</code> است؛ change تغییر حباب بر حسب واحد درصد است. برچسب را خودت از روی عدد دوباره حساب نکن. فقط ردیف‌های <code>HOT</code> را چاپ کن: هر خط <code>coin change</code>.</div>
#   <div class="box tip" dir="rtl"><b>راهنما:</b> تاپل را در حلقه باز کن و فقط وقتی <code>tag == "HOT"</code> بود چاپ کن.</div>
#
#   <div class="io">
#     <div class="pane in">
#       <div class="pane-label">ورودی نمونه</div>
#       <pre dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate;white-space:pre;">این سؤال ورودی ندارد</pre>
#     </div>
#     <div class="pane out">
#       <div class="pane-label">خروجی نمونه</div>
#       <pre dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate;white-space:pre;">Emami 2
# Quarter 4</pre>
#     </div>
#   </div>
#   <div class="box why" dir="rtl"><b>چرا این خروجی؟</b> چهار ردیف هست. نیم‌سکه یک واحد جمع شده و گرمی بدون تغییر است؛ هر دو OK هستند. امامی ۲ واحد و ربع‌سکه ۴ واحد داغ علامت خورده‌اند.</div>
# </div>

# %%
signals = [
    ("Emami", 2, "HOT"),
    ("Half", -1, "OK"),
    ("Quarter", 4, "HOT"),
    ("Gram", 0, "OK"),
]

# To Do: فقط ردیف‌های HOT را چاپ کن
for coin, change, tag in signals:
    # To Do: شرط برچسب داغ

# %% [markdown]
# ###### q18
#
# <div class="qcard" dir="rtl" align="right" style="direction:rtl;text-align:right;">
#   <div class="qbar" dir="rtl" style="direction:rtl;text-align:right;">
#     <span class="qnum">سؤال ۱۸</span>
#     <span class="tags">string · replace · if</span>
#   </div>
#   <h2 style="direction:rtl;text-align:right;">کد کثیف بازار ارز</h2>
#   <div class="qbody" dir="rtl" style="direction:rtl;text-align:right;">کد بازار ارز کثیف از فایل آمده است. اول آن را استاندارد کن و بعد نوع بازار را تشخیص بده. قواعد تمیزکاری به همین ترتیب:<br>۱) فاصله دو سر حذف شود.<br>۲) حروف بزرگ شود.<br>۳) کاراکتر <code>/</code> حذف شود.<br>بعد از تمیزکاری اگر با <code>F</code> شروع شد <code>Free</code>، اگر با <code>O</code> شروع شد <code>Official</code>، وگرنه <code>Unknown</code> چاپ کن.</div>
#   <div class="box tip" dir="rtl"><b>راهنما:</b> متدها را زنجیره کن: <code>s.strip().upper().replace("/", "")</code>. بعد با <code>if / elif / else</code> تصمیم بگیر. <code>elif</code> یعنی شرط قبلی غلط بوده و این شرط را امتحان کن. حرف اول را قبل از upper چک نکن.</div>
#
#   <div class="io">
#     <div class="pane in">
#       <div class="pane-label">ورودی نمونه</div>
#       <pre dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate;white-space:pre;">  f/usd </pre>
#     </div>
#     <div class="pane out">
#       <div class="pane-label">خروجی نمونه</div>
#       <pre dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate;white-space:pre;">Free</pre>
#     </div>
#   </div>
#   <div class="box why" dir="rtl"><b>چرا این خروجی؟</b> بعد از strip و upper و حذف اسلش می‌ماند FUSD. با F شروع می‌شود، پس Free است. اگر OUSD می‌ماند Official می‌شد و اگر مثلاً XAU می‌ماند Unknown.</div>
# </div>

# %%
raw = input()

# To Do: کد را تمیز کن و Free یا Official یا Unknown را چاپ کن

# %% [markdown]
# ###### q19
#
# <div class="qcard" dir="rtl" align="right" style="direction:rtl;text-align:right;">
#   <div class="qbar" dir="rtl" style="direction:rtl;text-align:right;">
#     <span class="qnum">سؤال ۱۹</span>
#     <span class="tags">dict · for</span>
#   </div>
#   <h2 style="direction:rtl;text-align:right;">شکاف دلار آزاد</h2>
#   <div class="qbody" dir="rtl" style="direction:rtl;text-align:right;">شکاف دلار یعنی دلار آزاد چند تومان از بازار دیگر گران‌تر است. اول n را بگیر، بعد n خط به شکل <code>MARKET RATE</code>. نرخ‌ها را در یک دیکشنری ذخیره کن. بعد دقیقاً این دو خط را چاپ کن:<br><code>Free-Official GAP</code><br><code>Free-Nima GAP</code><br>GAP اول برابر نرخ Free منهای Official است و GAP دوم برابر Free منهای Nima. ترتیب خط‌های ورودی مهم نیست.</div>
#   <div class="box tip" dir="rtl"><b>راهنما:</b> در حلقه بنویس <code>rates[market] = int(value)</code>. بعد از تمام شدن حلقه دو تفاضل را چاپ کن.</div>
#   <div class="box extra" dir="rtl"><b>راهنمای مفهوم کمکی:</b> شکاف با نرخ رسمی نشان می‌دهد دسترسی به ارز رسمی چقدر محدود است. شکاف با نیما معمولاً کوچک‌تر است، چون نیما خودش بین رسمی و آزاد قرار می‌گیرد.</div>
#   <div class="io">
#     <div class="pane in">
#       <div class="pane-label">ورودی نمونه</div>
#       <pre dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate;white-space:pre;">3
# Official 71000
# Free 87100
# Nima 74000</pre>
#     </div>
#     <div class="pane out">
#       <div class="pane-label">خروجی نمونه</div>
#       <pre dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate;white-space:pre;">Free-Official 16100
# Free-Nima 13100</pre>
#     </div>
#   </div>
#   <div class="box why" dir="rtl"><b>چرا این خروجی؟</b> آزاد ۸۷۱۰۰، رسمی ۷۱۰۰۰ و نیما ۷۴۰۰۰ است. ۸۷۱۰۰−۷۱۰۰۰=۱۶۱۰۰ و ۸۷۱۰۰−۷۴۰۰۰=۱۳۱۰۰. هر دو خط باید چاپ شوند.</div>
# </div>

# %%
n = int(input())
rates = {}

for i in range(n):
    market, value = input().split()
    # To Do: نرخ این بازار را در دیکشنری ذخیره کن

# To Do: شکاف آزاد با رسمی و شکاف آزاد با نیما را چاپ کن

# %% [markdown]
# ###### q20
#
# <div class="qcard" dir="rtl" align="right" style="direction:rtl;text-align:right;">
#   <div class="qbar" dir="rtl" style="direction:rtl;text-align:right;">
#     <span class="qnum">سؤال ۲۰</span>
#     <span class="tags">dict · nested</span>
#   </div>
#   <h2 style="direction:rtl;text-align:right;">نرخ بهره حقیقی سال</h2>
#   <div class="qbody" dir="rtl" style="direction:rtl;text-align:right;">پرونده هر سال یک دیکشنری تو در تو است: تورم، رشد و نرخ سیاستی، همه به درصد. سال را از ورودی بگیر و سه خط چاپ کن، به همین ترتیب: تورم، رشد، و نرخ بهره حقیقی ساده. نرخ حقیقی ساده در این سؤال برابر است با نرخ سیاستی منهای تورم.</div>
#   <div class="box tip" dir="rtl"><b>راهنما:</b> اول پرونده سال را بردار: <code>info = macro[year]</code>. سال را int نکن؛ کلید دیکشنری متن است. بعد <code>info["inflation"]</code> و بقیه فیلدها را بخوان.</div>
#   <div class="box extra" dir="rtl"><b>راهنمای مفهوم کمکی:</b> اگر سود سپرده یا نرخ سیاستی از تورم کمتر باشد، قدرت خرید پول در بانک کم می‌شود. به همین اختلاف ساده می‌گویند نرخ بهره حقیقی. منفی بودنش یعنی دارایی اسمی از تورم عقب است.</div>
#   <div class="io">
#     <div class="pane in">
#       <div class="pane-label">ورودی نمونه</div>
#       <pre dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate;white-space:pre;">1404</pre>
#     </div>
#     <div class="pane out">
#       <div class="pane-label">خروجی نمونه</div>
#       <pre dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate;white-space:pre;">32
# 4
# -11</pre>
#     </div>
#   </div>
#   <div class="box why" dir="rtl"><b>چرا این خروجی؟</b> سال ۱۴۰۴ تورم ۳۲، رشد ۴ و نرخ سیاستی ۲۱ دارد. نرخ حقیقی ۲۱−۳۲=−۱۱ است و علامت منفی باید در خروجی بماند.</div>
# </div>

# %%
macro = {
    "1403": {"inflation": 35, "growth": 3, "policy": 23},
    "1404": {"inflation": 32, "growth": 4, "policy": 21},
}
year = input()

# To Do: تورم، رشد و نرخ حقیقی همین سال را در سه خط چاپ کن

# %% [markdown]
# ###### q21
#
# <div class="qcard" dir="rtl" align="right" style="direction:rtl;text-align:right;">
#   <div class="qbar" dir="rtl" style="direction:rtl;text-align:right;">
#     <span class="qnum">سؤال ۲۱</span>
#     <span class="tags">dict · list · for</span>
#   </div>
#   <h2 style="direction:rtl;text-align:right;">گروه‌بندی بازارهای حباب</h2>
#   <div class="qbody" dir="rtl" style="direction:rtl;text-align:right;">برای گزارش حباب باید نام‌ها را بر اساس بازار گروه‌بندی کنی. اول n را بگیر، بعد n خط <code>NAME MARKET</code>. یک دیکشنری بساز که کلیدش بازار و مقدارش لیست نام‌های همان بازار باشد. هر بازار را به ترتیب اولین ورود چاپ کن: <code>MARKET: N1 N2 ...</code></div>
#   <div class="box tip" dir="rtl"><b>راهنما:</b> اگر بازار هنوز در دیکشنری نبود، یک لیست خالی برایش بساز و بعد نام را <code>append</code> کن. پیمایش نهایی روی <code>groups.items()</code> باشد.</div>
#   <div class="box extra" dir="rtl"><b>راهنمای مفهوم کمکی:</b> این الگو را «گروه‌بندی» می‌گویند: دیکشنری از کلید به لیست. حباب فقط مال سکه نیست؛ ارز، مسکن و سهام هم می‌توانند از ارزش بنیادی فاصله بگیرند.</div>
#   <div class="io">
#     <div class="pane in">
#       <div class="pane-label">ورودی نمونه</div>
#       <pre dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate;white-space:pre;">5
# Emami Gold
# USD FX
# Tehran Housing
# Half Gold
# TSE Equity</pre>
#     </div>
#     <div class="pane out">
#       <div class="pane-label">خروجی نمونه</div>
#       <pre dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate;white-space:pre;">Gold: Emami Half
# FX: USD
# Housing: Tehran
# Equity: TSE</pre>
#     </div>
#   </div>
#   <div class="box why" dir="rtl"><b>چرا این خروجی؟</b> طلا اول می‌آید چون امامی اولین رکورد است و بعد نیم‌سکه به همان لیست اضافه می‌شود. سپس ارز، مسکن و سهام به ترتیب اولین دیده‌شدن می‌آیند.</div>
# </div>

# %%
n = int(input())
groups = {}

for i in range(n):
    name, market = input().split()
    # To Do: name را به لیست groups[market] اضافه کن

# To Do: هر بازار و نام‌هایش را چاپ کن

# %% [markdown]
# ###### q22
#
# <div class="qcard" dir="rtl" align="right" style="direction:rtl;text-align:right;">
#   <div class="qbar" dir="rtl" style="direction:rtl;text-align:right;">
#     <span class="qnum">سؤال ۲۲</span>
#     <span class="tags">for · if</span>
#   </div>
#   <h2 style="direction:rtl;text-align:right;">عبور حباب از سقف تحلیلی</h2>
#   <div class="qbody" dir="rtl" style="direction:rtl;text-align:right;">سقف حباب هر قطعه جداست، چون حق ضرب سکه کوچک را نباید با حباب سفته‌بازی یکی گرفت. اول n، بعد n خط <code>NAME BUBBLE CEILING</code> (هر دو عدد، درصد صحیح). فقط قطعه‌هایی را چاپ کن که حباب‌شان از سقف خودشان بیشتر است؛ هر خط <code>NAME GAP</code> و GAP برابر حباب منهای سقف است. ترتیب همان ترتیب ورودی باشد. اگر هیچ‌کدام عبور نکرده بودند چیزی چاپ نشود.</div>
#   <div class="box tip" dir="rtl"><b>راهنما:</b> عبور از سقف یعنی <code>bubble - ceiling</code> وقتی حباب اکیداً بزرگ‌تر از سقف است.</div>
#   <div class="box extra" dir="rtl"><b>راهنمای مفهوم کمکی:</b> گرمی در این نمونه ۵۵ درصد حباب دارد ولی سقف تحلیلی‌اش ۶۰ است؛ پس حبابش ساختاری است و نباید در فهرست هشدار بیاید.</div>
#   <div class="io">
#     <div class="pane in">
#       <div class="pane-label">ورودی نمونه</div>
#       <pre dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate;white-space:pre;">4
# Emami 18 15
# Half 27 25
# Quarter 41 35
# Gram 55 60</pre>
#     </div>
#     <div class="pane out">
#       <div class="pane-label">خروجی نمونه</div>
#       <pre dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate;white-space:pre;">Emami 3
# Half 2
# Quarter 6</pre>
#     </div>
#   </div>
#   <div class="box why" dir="rtl"><b>چرا این خروجی؟</b> امامی ۳ واحد، نیم‌سکه ۲ واحد و ربع‌سکه ۶ واحد بالای سقف خودشان هستند. گرمی ۵ واحد زیر سقف است و چاپ نمی‌شود.</div>
# </div>

# %%
n = int(input())

for i in range(n):
    name, bubble, ceiling = input().split()
    bubble = int(bubble)
    ceiling = int(ceiling)
    # To Do: اگر حباب از سقف بیشتر بود نام و فاصله را چاپ کن

# %% [markdown]
# ###### q23
#
# <div class="qcard" dir="rtl" align="right" style="direction:rtl;text-align:right;">
#   <div class="qbar" dir="rtl" style="direction:rtl;text-align:right;">
#     <span class="qnum">سؤال ۲۳</span>
#     <span class="tags">string · split · list</span>
#   </div>
#   <h2 style="direction:rtl;text-align:right;">حراج سکه بانک مرکزی</h2>
#   <div class="qbody" dir="rtl" style="direction:rtl;text-align:right;">نتیجه حراج سکه یک رشته است. معامله‌ها با <code> | </code> جدا شده‌اند و هر معامله این شکل را دارد:<br><code>SIDE COIN QTY @ PRICE</code><br>PRICE قیمت هر قطعه به تومان است. رشته را بگیر. برای هر معامله یک خط چاپ کن: <code>SIDE COIN QTY NOTIONAL</code> که ارزش معامله برابر تعداد × قیمت هر قطعه است.</div>
#   <div class="box tip" dir="rtl"><b>راهنما:</b> اول با <code>split(" | ")</code> معامله‌ها را جدا کن. هر معامله را با <code>split()</code> به واژه‌ها بشکن. علامت <code>@</code> را نادیده بگیر؛ تعداد و قیمت را <code>int</code> کن.</div>
#   <div class="box extra" dir="rtl"><b>راهنمای مفهوم کمکی:</b> حراج، قیمت را از تابلو جدا می‌کند: برنده تعداد مشخصی سکه را در قیمت کشف‌شده می‌خرد. ارزش معامله همان مبلغی است که جابه‌جا می‌شود.</div>
#   <div class="io">
#     <div class="pane in">
#       <div class="pane-label">ورودی نمونه</div>
#       <pre dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate;white-space:pre;">BUY Emami 2 @ 74800000 | SELL Half 1 @ 41200000</pre>
#     </div>
#     <div class="pane out">
#       <div class="pane-label">خروجی نمونه</div>
#       <pre dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate;white-space:pre;">BUY Emami 2 149600000
# SELL Half 1 41200000</pre>
#     </div>
#   </div>
#   <div class="box why" dir="rtl"><b>چرا این خروجی؟</b> معامله اول ۲×۷۴۸۰۰۰۰۰=۱۴۹۶۰۰۰۰۰ و دومی ۱×۴۱۲۰۰۰۰۰=۴۱۲۰۰۰۰۰. دو معامله با | جدا شده بودند.</div>
# </div>

# %%
auction = input()

# To Do: معامله‌ها را جدا کن و برای هر کدام side coin qty notional را چاپ کن

# %% [markdown]
# ###### q24
#
# <div class="qcard" dir="rtl" align="right" style="direction:rtl;text-align:right;">
#   <div class="qbar" dir="rtl" style="direction:rtl;text-align:right;">
#     <span class="qnum">سؤال ۲۴</span>
#     <span class="tags">set · intersection · difference</span>
#   </div>
#   <h2 style="direction:rtl;text-align:right;">جهان مجاز صندوق طلا</h2>
#   <div class="qbody" dir="rtl" style="direction:rtl;text-align:right;">جهان مجاز صندوق طلا این‌طور ساخته می‌شود:<br>خط ۱: قطعه‌های داخل امیدنامه (mandate)<br>خط ۲: قطعه‌های نقدشونده (liquid)<br>خط ۳: قطعه‌های ممنوع به‌خاطر حباب (restricted)<br>مجموعه مجاز برابر است با اشتراک امیدنامه و نقدشونده، منهای ممنوع. اول تعداد قطعه‌های مجاز و در خط بعد همان‌ها را الفبایی با فاصله چاپ کن.</div>
#   <div class="box tip" dir="rtl"><b>راهنما:</b> سه <code>set</code> بساز. اشتراک <code>&amp;</code> و تفاضل <code>-</code>. خروجی را <code>sorted</code> کن.</div>
#   <div class="box extra" dir="rtl"><b>راهنمای مفهوم کمکی:</b> بهارآزادی نقد است ولی در امیدنامه این صندوق نیست. نیم‌سکه در امیدنامه هست ولی در فهرست نقدشونده نیست. ربع‌سکه هر دو شرط را دارد اما حبابش از حد ریسک گذشته و حذف می‌شود.</div>
#   <div class="io">
#     <div class="pane in">
#       <div class="pane-label">ورودی نمونه</div>
#       <pre dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate;white-space:pre;">Emami Half Quarter Gram
# Emami Quarter Gram Bahar
# Quarter</pre>
#     </div>
#     <div class="pane out">
#       <div class="pane-label">خروجی نمونه</div>
#       <pre dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate;white-space:pre;">2
# Emami Gram</pre>
#     </div>
#   </div>
#   <div class="box why" dir="rtl"><b>چرا این خروجی؟</b> اشتراک امیدنامه و نقدشونده: امامی، ربع‌سکه، گرمی. ربع‌سکه ممنوع است. می‌ماند امامی و گرمی.</div>
# </div>

# %%
mandate = set(input().split())
liquid = set(input().split())
restricted = set(input().split())

# To Do: مجموعه مجاز را بساز، تعداد و لیست مرتب را چاپ کن

# %% [markdown]
# ###### q25
#
# <div class="qcard" dir="rtl" align="right" style="direction:rtl;text-align:right;">
#   <div class="qbar" dir="rtl" style="direction:rtl;text-align:right;">
#     <span class="qnum">سؤال ۲۵</span>
#     <span class="tags">string · dict · slicing</span>
#   </div>
#   <h2 style="direction:rtl;text-align:right;">اعتبارسنجی کد تورم</h2>
#   <div class="qbody" dir="rtl" style="direction:rtl;text-align:right;">کد گزارش کلان را بگیر و شاخص را از روی آن بشناس. دیکشنری شاخص‌ها آماده است. قواعد، به همین ترتیب:<br>۱) فاصله‌ها را حذف کن و حروف را بزرگ کن.<br>۲) باید با <code>IR</code> شروع شود.<br>۳) طول کل باید دقیقاً ۹ کاراکتر باشد.<br>۴) دو کاراکتر سال، ایندکس ۲ تا ۴، باید رقم باشند.<br>۵) سه کاراکتر شاخص، ایندکس ۴ تا ۷، باید در دیکشنری باشد.<br>۶) دو کاراکتر ماه، ایندکس ۷ تا ۹، باید رقم باشند و عدد ماه بین ۱ و ۱۲ باشد.<br>اگر همه قواعد برقرار بود نام شاخص را چاپ کن؛ وگرنه <code>Invalid</code>. قبل از <code>int</code> کردن ماه، رقم بودن را چک کن وگرنه متن بد خطا می‌دهد.</div>
#   <div class="box tip" dir="rtl"><b>راهنما:</b> برش <code>s[a:b]</code> از a تا قبل از b را می‌دهد. <code>replace(" ", "")</code> فاصله‌های وسط را هم برمی‌دارد. در شرط‌های پشت‌سرهم با <code>and</code>، اگر یک شرط غلط شود شرط بعدی اجرا نمی‌شود؛ پس <code>isdigit</code> را قبل از <code>int</code> بگذار.</div>
#   <div class="box extra" dir="rtl"><b>راهنمای مفهوم کمکی:</b> چیدمان کد بعد از تمیزکاری: IR، بعد سال دو رقمی، بعد نماد سه‌حرفی شاخص، بعد ماه دو رقمی. 04 سال، CPI تورم مصرف‌کننده و 06 ماه ششم است. PPI تورم تولیدکننده و M2Y رشد نقدینگی است.</div>
#   <div class="io">
#     <div class="pane in">
#       <div class="pane-label">ورودی نمونه</div>
#       <pre dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate;white-space:pre;">ir 04 cpi 06</pre>
#     </div>
#     <div class="pane out">
#       <div class="pane-label">خروجی نمونه</div>
#       <pre dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate;white-space:pre;">Inflation</pre>
#     </div>
#   </div>
#   <div class="box why" dir="rtl"><b>چرا این خروجی؟</b> بعد از حذف فاصله و upper، متن IR04CPI06 است: طول ۹، شروع با IR، سال ۰۴ رقم است، CPI در دیکشنری است و ماه ۰۶ بین ۱ و ۱۲ است. خروجی Inflation است. ماه ۱۳ یا شاخص ناشناس Invalid می‌شد.</div>
# </div>

# %%
indicators = {
    "CPI": "Inflation",
    "PPI": "Producer",
    "M2Y": "Liquidity",
}
raw = input()

# To Do: کد را تمیز و اعتبارسنجی کن؛ نام شاخص یا Invalid را چاپ کن

# %% [markdown]
# <div class="guide" dir="rtl" align="right" style="direction:rtl;text-align:right;">
#   <h2 style="direction:rtl;text-align:right;">پایان تمرین‌ها</h2>
#   <p>اگر هر ۲۵ سؤال را خودت کامل کرده باشی، این مهارت‌ها را در عمل دیده‌ای:</p>
#   <ul>
#     <li>ایندکس و برش لیست، <code>append</code>، <code>count</code>، <code>join</code></li>
#     <li>خواندن و به‌روزرسانی دیکشنری، دیکشنری تو در تو، گروه‌بندی با دیکشنریِ لیست</li>
#     <li>تاپل برای مظنه اونس و دستور جلسه سیاست پولی، باز کردن تاپل در حلقه</li>
#     <li>مجموعه برای محرک تورم، ماه مشترک، و جهان مجاز صندوق طلا</li>
#     <li>متدهای رشته برای کد ارز، چاپ تورم، تابلوی سکه، حراج و کد گزارش کلان</li>
#     <li>موقعیت‌های اقتصادی مثل حباب سکه، شکاف دلار، نرخ بهره حقیقی و سقف تحلیلی حباب</li>
#   </ul>
#   <p>اگر جایی گیر کردی، اول راهنمای زرد همان سؤال را بخوان، بعد فقط همان خط <span class="kbd"># To Do</span> را عوض کن.</p>
# </div>
